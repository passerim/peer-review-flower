# %%
# Multiple ways to import prflwr whether it is installed
# as a Python module, in a Colab environment or if source
# code is in a parent directory for local development.
def import_prflwr():
    import os
    try: import prflwr; return
    except: pass
    if "setup.py" in os.listdir("../.."):
        os.chdir("../..")
        try: import prflwr
        except: pass
        finally: os.chdir("experiments/fedls")
        if prflwr: return
    try:
        import google.colab
        os.system(
            "pip install git+https://github.com/passerim/peer-review-flower.git"
        )
        import prflwr; return
    except: raise ModuleNotFoundError("No module named 'prflwr'")


import_prflwr()

# %%
import json
from copy import deepcopy as cp
from typing import Any, Dict, List, Optional, Tuple, Union

import flwr as fl
import matplotlib.pyplot as plt
import numpy as np
from flwr.common import (
    Code,
    EvaluateIns,
    EvaluateRes,
    Parameters,
    Scalar,
    Status,
    ndarrays_to_parameters,
    parameters_to_ndarrays,
)
from flwr.server import ClientManager, ServerConfig
from flwr.server.client_proxy import ClientProxy
from sklearn.cluster import KMeans
from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.tree._tree import Tree

from prflwr.peer_review import (
    PeerReviewClient,
    PeerReviewServer,
    ReviewIns,
    ReviewRes,
    TrainIns,
    TrainRes,
)
from prflwr.peer_review.strategy import (
    AggregateReviewException,
    AggregateTrainException,
    PeerReviewedFedAvg,
)
from prflwr.simulation import start_simulation

# %%
# Training configurations
NUM_CLIENTS = 30
FRACTION_TRAIN = 1 / 3
FRACTION_REVIEW = 1 / 3
FRACTION_EVAL = 0  # No federated evaluation
NUM_ROUNDS = 50

# Model hyperparameter
MAX_LEAVES = 8

# Useful constants
OK_STATUS = Status(Code.OK, "")

# Create rng for reproducibility
SEED = 0

# %%
# Load data
DATA_HOME = "./data"
data_x, data_y = fetch_california_housing(
    data_home=DATA_HOME, return_X_y=True, as_frame=True
)
x_train, x_test, y_train, y_test = train_test_split(
    data_x, data_y, test_size=0.2, shuffle=True, random_state=SEED
)
x_train, y_train = x_train[(y_train < 5)], y_train[(y_train < 5)]
x_test, y_test = x_test[(y_test < 5)], y_test[(y_test < 5)]

# %%
x_train.head(10)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 15925  4.3898      52.0  5.326622   1.100671      1485.0  3.322148     37.73
# 11162  3.9333      26.0  4.668478   1.046196      1022.0  2.777174     33.83
# 4904   1.4653      38.0  3.383495   1.009709       749.0  3.635922     34.01
# 4683   3.1765      52.0  4.119792   1.043403      1135.0  1.970486     34.08
# 8839   3.5114      52.0  4.411348   1.078014       444.0  1.574468     34.08
# 12439  2.2141      25.0  4.375758   0.990909      2940.0  4.454545     33.67
# 3094   1.8819      16.0  6.686493   1.464684      1802.0  2.232962     35.58
# 7107   4.6000      34.0  5.332258   0.941935      1003.0  3.235484     33.89
# 18750  2.1458      22.0  5.287611   1.070796      1131.0  2.502212     40.71
# 19133  2.4117      16.0  4.933657   0.985437      1675.0  2.710356     38.35
#
#        Longitude
# 15925    -122.44
# 11162    -118.00
# 4904     -118.26
# 4683     -118.36
# 8839     -118.39
# 12439    -116.18
# 3094     -118.45
# 7107     -118.01
# 18750    -122.40
# 19133    -122.72

# %%
# Train a centralized GBT model for regression
reg = GradientBoostingRegressor(
    criterion="squared_error",
    n_estimators=int(NUM_ROUNDS * (NUM_CLIENTS * FRACTION_TRAIN)),
    subsample=1 / NUM_CLIENTS,
    init="zero",
    max_leaf_nodes=MAX_LEAVES,
    random_state=SEED,
)
reg.fit(x_train, y_train)

# Print performance metrics measured on the test data
reg_pred = reg.predict(x_test)
print("r2_score:", r2_score(y_test, reg_pred))
print("mean_squared_error:", mean_squared_error(y_test, reg_pred))
# Out:
# r2_score: 0.7220518128079466
# mean_squared_error: 0.2608474566292749

# %%
# Inspect the distribution of the latitude and longitude of the samples
# There are natural clusters of samples with a similar value for the target variable
# Latitude and lognitude features will be used to split the samples in a non-iid way
def get_coordinates(data):
    return data[["Latitude", "Longitude"]].to_numpy()


plt.scatter(*get_coordinates(x_train).T, c=y_train)
plt.show()

# %%
# Cluster samples based on latitude and longitude
kmeans = KMeans(NUM_CLIENTS, random_state=SEED)
train_clusters = kmeans.fit_predict(get_coordinates(x_train))
test_clusters = kmeans.predict(get_coordinates(x_test))
plt.scatter(*get_coordinates(x_train).T, c=train_clusters)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Test performances of a random regressor on the test data
# The r2 score is meaningless in this case!
print("r2_score:", r2_score([y_train.mean(),] * len(y_test), y_test))
print("mean_squared_error:", mean_squared_error([y_train.mean(),] * len(y_test), y_test))
# Out:
# r2_score: -1.9035693802001623e+31
# mean_squared_error: 0.9385321652598128

# %%
# Simulation of the FedLSBT algorithm useful for experimental purposes
DEBUG = True


def fit(
    X,
    y,
    *,
    eta=1.0,
    base_estimator=ExtraTreeRegressor,
    n_estimators=50,
    fraction_train=1.0,
    fraction_review=1.0,
    sample_for_review=False,
    random_state=0,
):
    rng = np.random.default_rng(random_state)
    train_clients = max(
        0, min(kmeans.n_clusters, int(fraction_train * kmeans.n_clusters))
    )
    if sample_for_review:
        review_clients = max(
            0, min(kmeans.n_clusters, int(fraction_review * kmeans.n_clusters))
        )
    else:
        review_clients = train_clients
    if DEBUG:
        print(
            f"[DEBUG] train_clients: {train_clients}, review_clients: {review_clients}"
        )
    model = {"estimators": [], "gammas": []}
    losses = []
    y_predf = 0
    for _ in range(n_estimators):
        train_subset = rng.choice(np.unique(kmeans.labels_), train_clients, False)
        if DEBUG:
            print(f"[DEBUG] random clients train subset: {train_subset}")
        candidates = {"trees": [], "gamma_numerator": [], "gamma_denominator": []}
        ri = y - y_predf
        # -#-#-#-#-#-#-#-#- Client Training -#-#-#-#-#-#-#-#-#-#-#
        for i in train_subset:
            tree = base_estimator(max_leaf_nodes=MAX_LEAVES, random_state=i**2)
            tree.fit(X.iloc[train_clusters == i], ri.iloc[train_clusters == i])
            candidates["trees"].append(tree)
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        # -#-#-#-#-#-#-#-#- Client Review -#-#-#-#-#-#-#-#-#-#-#-#
        if sample_for_review:
            review_subset = rng.choice(np.unique(kmeans.labels_), review_clients, False)
        else:
            review_subset = train_subset
        if DEBUG:
            print(f"[DEBUG] random clients review subset: {review_subset}")
        for n, i in enumerate(review_subset):
            h_k = [
                tree.predict(X.iloc[train_clusters == i])
                # if n != m
                # else np.zeros(len(X.iloc[train_clusters == i]))
                for m, tree in enumerate(candidates["trees"])
            ]
            h_k = np.stack(h_k, axis=1).T
            numerator_k = h_k @ ri.iloc[train_clusters == i]
            denominator_k = h_k @ h_k.T
            candidates["gamma_numerator"].append(numerator_k)
            candidates["gamma_denominator"].append(denominator_k)
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        # -#-#-#-#-#-#-#-#- Server Aggregate -#-#-#-#-#-#-#-#-#-#-
        if len(candidates["gamma_numerator"]) > 0:
            gamma_numerator = sum(candidates["gamma_numerator"])
            gamma_denominator = sum(candidates["gamma_denominator"])
            gamma = np.linalg.inv(gamma_denominator) @ gamma_numerator
        else:
            gamma = np.ones(len(candidates["trees"]))
        gamma = gamma / (len(gamma))
        gamma = gamma * eta
        for i, tree in enumerate(candidates["trees"]):
            y_predf = y_predf + gamma[i] * tree.predict(X)
            model["estimators"].append(tree)
            model["gammas"].append(gamma[i])
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        losses.append(mean_squared_error(y_predf, y))
    return model, losses


def predict(X, model):
    y_pred = np.zeros(X.shape[0])
    for estimator, gamma in zip(model["estimators"], model["gammas"]):
        y_pred = y_pred + gamma * estimator.predict(X)
    return y_pred

# %%
# Train the FedLSBT model
model, losses = fit(
    x_train,
    y_train,
    base_estimator=ExtraTreeRegressor,
    n_estimators=NUM_ROUNDS,
    fraction_train=FRACTION_TRAIN,
    fraction_review=FRACTION_REVIEW,
    random_state=SEED,
)
# Out:
# [DEBUG] train_clients: 10, review_clients: 10
# [DEBUG] random clients train subset: [17 24 14 11  6  1  0  7  5  2]
# [DEBUG] random clients review subset: [17 24 14 11  6  1  0  7  5  2]
# [DEBUG] random clients train subset: [28 16  0 18 23 10 19  6 22 15]
# [DEBUG] random clients review subset: [28 16  0 18 23 10 19  6 22 15]
# [DEBUG] random clients train subset: [ 9 10 15  0 24 18 19 26  3 22]
# [DEBUG] random clients review subset: [ 9 10 15  0 24 18 19 26  3 22]
# [DEBUG] random clients train subset: [14 23  3 18 10 20 22 17 29 24]
# [DEBUG] random clients review subset: [14 23  3 18 10 20 22 17 29 24]
# [DEBUG] random clients train subset: [ 9 28  1 17 16 20 12  6  8 14]
# [DEBUG] random clients review subset: [ 9 28  1 17 16 20 12  6  8 14]
# [DEBUG] random clients train subset: [ 1  9 21  8 10 22 20 23 13  6]
# [DEBUG] random clients review subset: [ 1  9 21  8 10 22 20 23 13  6]
# [DEBUG] random clients train subset: [28 15 16  5 17  1 11 19 18 29]
# [DEBUG] random clients review subset: [28 15 16  5 17  1 11 19 18 29]
# [DEBUG] random clients train subset: [ 2 21  9 16  4 25 14 18  1 22]
# [DEBUG] random clients review subset: [ 2 21  9 16  4 25 14 18  1 22]
# [DEBUG] random clients train subset: [ 8 28 24 19  0 13 12 23 22 15]
# [DEBUG] random clients review subset: [ 8 28 24 19  0 13 12 23 22 15]
# [DEBUG] random clients train subset: [22 16 24 23  4 15 21 27  3 29]
# [DEBUG] random clients review subset: [22 16 24 23  4 15 21 27  3 29]
# [DEBUG] random clients train subset: [ 3  9 24 17 11 25 21 29 12  8]
# [DEBUG] random clients review subset: [ 3  9 24 17 11 25 21 29 12  8]
# [DEBUG] random clients train subset: [ 1 25  3 12 24  5 15 11  9 19]
# [DEBUG] random clients review subset: [ 1 25  3 12 24  5 15 11  9 19]
# [DEBUG] random clients train subset: [27 14 22 12 25 16  3 24  1  7]
# [DEBUG] random clients review subset: [27 14 22 12 25 16  3 24  1  7]
# [DEBUG] random clients train subset: [11  3 23 28 24  6 25  5 27 16]
# [DEBUG] random clients review subset: [11  3 23 28 24  6 25  5 27 16]
# [DEBUG] random clients train subset: [11  6 12 18 13  1 10 25 23 22]
# [DEBUG] random clients review subset: [11  6 12 18 13  1 10 25 23 22]
# [DEBUG] random clients train subset: [20  3 29  1 17 10 24 19 26 28]
# [DEBUG] random clients review subset: [20  3 29  1 17 10 24 19 26 28]
# [DEBUG] random clients train subset: [ 7 13 15 18 28  5 25  2  1 19]
# [DEBUG] random clients review subset: [ 7 13 15 18 28  5 25  2  1 19]
# [DEBUG] random clients train subset: [23  0  6 29  9 18  8 20 24 11]
# [DEBUG] random clients review subset: [23  0  6 29  9 18  8 20 24 11]
# [DEBUG] random clients train subset: [12 21 29  4 24  7 28  1 26 16]
# [DEBUG] random clients review subset: [12 21 29  4 24  7 28  1 26 16]
# [DEBUG] random clients train subset: [18 24  1  3  5  2 20 13 26 21]
# [DEBUG] random clients review subset: [18 24  1  3  5  2 20 13 26 21]
# [DEBUG] random clients train subset: [ 8  4 18 17 28  2 29 12 13 15]
# [DEBUG] random clients review subset: [ 8  4 18 17 28  2 29 12 13 15]
# [DEBUG] random clients train subset: [ 7 19 21 16 12 29 18  4  5  9]
# [DEBUG] random clients review subset: [ 7 19 21 16 12 29 18  4  5  9]
# [DEBUG] random clients train subset: [ 4 25 16 20 17 10  1 21 11  7]
# [DEBUG] random clients review subset: [ 4 25 16 20 17 10  1 21 11  7]
# [DEBUG] random clients train subset: [ 7 17 29 28 16 22 24  3  2 19]
# [DEBUG] random clients review subset: [ 7 17 29 28 16 22 24  3  2 19]
# [DEBUG] random clients train subset: [ 2  7 18 21  8 15  5 14 12  0]
# [DEBUG] random clients review subset: [ 2  7 18 21  8 15  5 14 12  0]
# [DEBUG] random clients train subset: [16 20  7  4 11 24  1 12 13 27]
# [DEBUG] random clients review subset: [16 20  7  4 11 24  1 12 13 27]
# [DEBUG] random clients train subset: [13  1 20  9 27 10 21 22 14  2]
# [DEBUG] random clients review subset: [13  1 20  9 27 10 21 22 14  2]
# [DEBUG] random clients train subset: [20 18 17 27  1 21 23 26  7 19]
# [DEBUG] random clients review subset: [20 18 17 27  1 21 23 26  7 19]
# [DEBUG] random clients train subset: [23  4 10 12  2 22  8 11  0 13]
# [DEBUG] random clients review subset: [23  4 10 12  2 22  8 11  0 13]
# [DEBUG] random clients train subset: [19 18 28  1 20 12  0 26 10  8]
# [DEBUG] random clients review subset: [19 18 28  1 20 12  0 26 10  8]
# [DEBUG] random clients train subset: [25  6 15 26 19 29  2 27  7 20]
# [DEBUG] random clients review subset: [25  6 15 26 19 29  2 27  7 20]
# [DEBUG] random clients train subset: [25  6 10  8 13 23  3 27  7 19]
# [DEBUG] random clients review subset: [25  6 10  8 13 23  3 27  7 19]
# [DEBUG] random clients train subset: [13 24 15 29 25 22 12  6 19  2]
# [DEBUG] random clients review subset: [13 24 15 29 25 22 12  6 19  2]
# [DEBUG] random clients train subset: [ 9 22  8  3  5 18 29 19 28 13]
# [DEBUG] random clients review subset: [ 9 22  8  3  5 18 29 19 28 13]
# [DEBUG] random clients train subset: [27 15 19  1  5 28 20  8 16  4]
# [DEBUG] random clients review subset: [27 15 19  1  5 28 20  8 16  4]
# [DEBUG] random clients train subset: [ 4  5 22 10  0 15  1 12 23 16]
# [DEBUG] random clients review subset: [ 4  5 22 10  0 15  1 12 23 16]
# [DEBUG] random clients train subset: [ 7  8 26 17  2 23 22 18 25 15]
# [DEBUG] random clients review subset: [ 7  8 26 17  2 23 22 18 25 15]
# [DEBUG] random clients train subset: [ 9 17 23  3 26 13  7  5 16  4]
# [DEBUG] random clients review subset: [ 9 17 23  3 26 13  7  5 16  4]
# [DEBUG] random clients train subset: [20 26  6 18 22  2  0 11 25 12]
# [DEBUG] random clients review subset: [20 26  6 18 22  2  0 11 25 12]
# [DEBUG] random clients train subset: [10  3  5 15 20 26 18  9 22 11]
# [DEBUG] random clients review subset: [10  3  5 15 20 26 18  9 22 11]
# [DEBUG] random clients train subset: [ 0 24  4  9 11 25  7  3 27 18]
# [DEBUG] random clients review subset: [ 0 24  4  9 11 25  7  3 27 18]
# [DEBUG] random clients train subset: [11 26 19 16 22 18 17 12 14 28]
# [DEBUG] random clients review subset: [11 26 19 16 22 18 17 12 14 28]
# [DEBUG] random clients train subset: [ 4 19 28  2  8 25 26 24 21  0]
# [DEBUG] random clients review subset: [ 4 19 28  2  8 25 26 24 21  0]
# [DEBUG] random clients train subset: [13 23  3 28 20 16 18 24 19 15]
# [DEBUG] random clients review subset: [13 23  3 28 20 16 18 24 19 15]
# [DEBUG] random clients train subset: [ 6 25 26  7  3  8  2 28 23 13]
# [DEBUG] random clients review subset: [ 6 25 26  7  3  8  2 28 23 13]
# [DEBUG] random clients train subset: [22 15 18 17  7  9  4 24  2 11]
# [DEBUG] random clients review subset: [22 15 18 17  7  9  4 24  2 11]
# [DEBUG] random clients train subset: [29 18 21 19 10  6 24 12 28  5]
# [DEBUG] random clients review subset: [29 18 21 19 10  6 24 12 28  5]
# [DEBUG] random clients train subset: [10 23  6 12  4 22 29  8 17 20]
# [DEBUG] random clients review subset: [10 23  6 12  4 22 29  8 17 20]
# [DEBUG] random clients train subset: [24 14 19 26  9 17 20  4 29  1]
# [DEBUG] random clients review subset: [24 14 19 26  9 17 20  4 29  1]
# [DEBUG] random clients train subset: [22 25 13  2 27 26 23 12  9  4]
# [DEBUG] random clients review subset: [22 25 13  2 27 26 23 12  9  4]

# %%
# Measure the performance of the FedLSBT model on the test data
print("r2_score:", r2_score(y_test, predict(x_test, model)))
print("mean_squared_error:", mean_squared_error(y_test, predict(x_test, model)))
# Out:
# r2_score: 0.3812442930471408
# mean_squared_error: 0.3171917145909822

# %%
# Plots about the coefficients and losses during training
plt.plot(model["gammas"][::10])
plt.plot(losses)
print("mean_gamma", sum(model["gammas"]) / len(model["gammas"]))
# Out:
# mean_gamma 0.015585469713270815

# %%
# Implementation of the FedLSBT model serialization


def tree_to_state_dict(tree: Tree) -> Dict[str, Any]:
    serialized_tree = tree.__getstate__()
    dtypes = serialized_tree["nodes"].dtype
    serialized_tree["nodes_dtype"] = [dtypes[i].str for i in range(0, len(dtypes))]
    serialized_tree["nodes"] = serialized_tree["nodes"].tolist()
    serialized_tree["values"] = serialized_tree["values"].tolist()
    return serialized_tree


def decision_tree_regressor_to_state_dict(
    model: DecisionTreeRegressor,
) -> Dict[str, Any]:
    serialized_model = model.__getstate__()
    tree = tree_to_state_dict(model.tree_)
    serialized_model["feature_names_in_"] = model.feature_names_in_.tolist()
    serialized_model["tree_"] = tree
    return serialized_model


def serialize_decision_tree_regressor(model: DecisionTreeRegressor) -> bytes:
    model_state_dict = decision_tree_regressor_to_state_dict(model)
    json_formatted = json.dumps(model_state_dict)
    return bytes(json_formatted, "utf-8")


def state_dict_to_tree(
    tree_dict: Dict[str, Any], n_features: int, n_classes: int, n_outputs: int
):
    tree_dict["nodes"] = [tuple(lst) for lst in tree_dict["nodes"]]
    names = [
        "left_child",
        "right_child",
        "feature",
        "threshold",
        "impurity",
        "n_node_samples",
        "weighted_n_node_samples",
    ]
    tree_dict["nodes"] = np.array(
        tree_dict["nodes"],
        dtype=np.dtype({"names": names, "formats": tree_dict["nodes_dtype"]}),
    )
    tree_dict["values"] = np.array(tree_dict["values"])
    tree = Tree(n_features, np.array([n_classes], dtype=np.intp), n_outputs)
    tree.__setstate__(tree_dict)
    return tree


def state_dict_to_decision_tree_regressor(model_dict: Dict[str, Any]):
    deserialized_decision_tree = DecisionTreeRegressor()
    for key, value in iter(model_dict.items()):
        if key == "feature_names_in_":
            setattr(deserialized_decision_tree, key, np.asarray(value))
        elif key != "tree_":
            setattr(deserialized_decision_tree, key, value)
    tree = state_dict_to_tree(
        model_dict["tree_"], model_dict["n_features_in_"], 1, model_dict["n_outputs_"]
    )
    deserialized_decision_tree.tree_ = tree
    return deserialized_decision_tree


def deserialize_decision_tree_regressor(
    model_serialized: bytes,
) -> DecisionTreeRegressor:
    json_formatted = str(model_serialized, "utf-8")
    model_state_dict = json.loads(json_formatted)
    return state_dict_to_decision_tree_regressor(model_state_dict)


class FederatedGradientBoostingRegressor:
    def __init__(self):
        self.estimators_ = []
        self.gammas_ = []

    def predict(self, x):
        y_pred = np.zeros(x.shape[0])
        for estimator, gamma in zip(self.estimators_, self.gammas_):
            y_pred = y_pred + gamma * estimator.predict(x)
        return y_pred

    def add_estimator(self, estimator, gamma):
        if not self.estimators_:
            self.max_features_ = estimator.max_features_
            self.n_features_in_ = estimator.n_features_in_
        for attr in ["max_features_", "n_features_in_"]:
            if getattr(self, attr) != getattr(estimator, attr):
                return
        self.estimators_.append(estimator)
        self.gammas_.append(gamma)


def gradient_boosting_to_state_dict(
    model: FederatedGradientBoostingRegressor,
) -> Dict[str, Any]:
    serialized_model = {
        "estimators_": [],
        "gammas_": model.gammas_,
    }
    if getattr(model, "max_features_", None):
        serialized_model["max_features_"] = model.max_features_
    if getattr(model, "n_features_in_", None):
        serialized_model["n_features_in_"] = model.n_features_in_
    for tree in model.estimators_:
        serialized_model["estimators_"].append(
            decision_tree_regressor_to_state_dict(tree)
        )
    return serialized_model


def state_dict_to_gradient_boosting(
    model_dict: Dict[str, Any]
) -> FederatedGradientBoostingRegressor:
    model = FederatedGradientBoostingRegressor()
    model.estimators_ = [
        state_dict_to_decision_tree_regressor(tree)
        for tree in model_dict["estimators_"]
    ]
    model.gammas_ = model_dict["gammas_"]
    if model_dict.get("max_features_", False):
        model.max_features_ = model_dict["max_features_"]
    if model_dict.get("max_features_", False):
        model.n_features_in_ = model_dict["n_features_in_"]
    return model


def serialize_gradient_boosting_regressor(
    model: FederatedGradientBoostingRegressor,
) -> bytes:
    json_formatted = json.dumps(gradient_boosting_to_state_dict(model))
    return bytes(json_formatted, "utf-8")


def deserialize_gradient_boosting_regressor(
    model_serialized: bytes,
) -> FederatedGradientBoostingRegressor:
    json_formatted = str(model_serialized, "utf-8")
    model_dict = json.loads(json_formatted)
    return state_dict_to_gradient_boosting(model_dict)


def serialize_global_model_and_candidates(
    model: Union[FederatedGradientBoostingRegressor, bytes],
    candidates: Union[List[DecisionTreeRegressor], bytes],
) -> bytes:
    if isinstance(model, bytes):
        model = deserialize_gradient_boosting_regressor(model)
    if isinstance(candidates[0], bytes):
        candidates = [deserialize_decision_tree_regressor(tree) for tree in candidates]
    serialized_models = dict(
        global_model=gradient_boosting_to_state_dict(model),
        candidate_models=[
            decision_tree_regressor_to_state_dict(tree) for tree in candidates
        ],
    )
    json_serialized = json.dumps(serialized_models)
    return bytes(json_serialized, "utf-8")

# %%
# FedLSBT client implementation with PeerReview-Flower


class FedLSBTClient(PeerReviewClient):
    def __init__(
        self,
        cid: int,
        trainset: Tuple[np.ndarray, np.array],
        testset: Tuple[np.ndarray, np.array],
    ):
        self.cid = cid
        self.trainset = trainset
        self.testset = testset

    def train(self, ins: TrainIns) -> TrainRes:
        parameters, config = ins.parameters, ins.config
        model = deserialize_gradient_boosting_regressor(parameters.tensors[0])
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        ri = self.trainset[1] - model.predict(self.trainset[0])
        tree = ExtraTreeRegressor(
            max_leaf_nodes=config.get("max_leaves", MAX_LEAVES),
            random_state=self.cid**2,
        )
        tree.fit(self.trainset[0], ri)
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        res = TrainRes(
            OK_STATUS,
            Parameters(
                tensors=[serialize_decision_tree_regressor(tree)], tensor_type="bytes"
            ),
            len(self.trainset[1]),
            {},
        )
        return res

    def review(self, ins: ReviewIns) -> ReviewRes:
        parameters = ins.parameters
        state_dicts = json.loads(str(parameters.tensors[0], "utf-8"))
        model = state_dict_to_gradient_boosting(state_dicts["global_model"])
        candidates = [
            state_dict_to_decision_tree_regressor(tree)
            for tree in state_dicts["candidate_models"]
        ]
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-##-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        res_model = self.trainset[1] - model.predict(self.trainset[0])
        res_candidates = [tree.predict(self.trainset[0]) for tree in candidates]
        res_candidates = np.stack(res_candidates, axis=1).T
        numerator_k = res_candidates @ res_model
        denominator_k = res_candidates @ res_candidates.T
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-##-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        res = ReviewRes(
            OK_STATUS,
            ndarrays_to_parameters([numerator_k, denominator_k]),
            len(self.trainset[1]),
            {},
        )
        return res

    def evaluate(self, ins: EvaluateIns) -> EvaluateRes:
        parameters, _ = ins.parameters, ins.config
        model = deserialize_gradient_boosting_regressor(parameters.tensors[0])
        y_pred = model.predict(self.testset[0])
        loss = mean_squared_error(self.testset[1], y_pred)
        return EvaluateRes(OK_STATUS, loss, len(self.testset[1]), {})

# %%
# FedLSBT strategy implementation with PeerReview-Flower


class FederatedGradientBoostingStrategy(PeerReviewedFedAvg):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def aggregate_train(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, TrainRes]],
        failures: List[Union[Tuple[ClientProxy, TrainRes], BaseException]],
        parameters: Optional[Parameters] = None,
    ) -> List[Tuple[Optional[Parameters], Dict[str, Scalar]]]:
        if not results:
            raise AggregateTrainException
        # Do not aggregate if there are failures and failures are not accepted
        if not self.accept_failures and failures:
            raise AggregateTrainException

        # Save ClientProxies
        self.current_round_clients = [proxy for proxy, _ in results]

        # Collect results
        return [(fit_res.parameters, {}) for _, fit_res in results]

    def configure_review(
        self,
        server_round: int,
        review_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
        parameters_aggregated: List[Optional[Parameters]],
        metrics_aggregated: List[Dict[str, Scalar]],
    ) -> List[Tuple[ClientProxy, ReviewIns]]:
        # Make instructions and configurations
        config = {}
        if self.on_review_config_fn is not None:
            # Custom review config function provided
            config = self.on_review_config_fn(server_round)
        # Serialize current gloabal model and candidates
        serialized = serialize_global_model_and_candidates(
            parameters.tensors[0],
            [params.tensors[0] for params in parameters_aggregated],
        )
        review_ins = ReviewIns(
            Parameters(tensors=[serialized], tensor_type="bytes"), config
        )

        # Return client/config pairs
        return [(client, review_ins) for client in self.current_round_clients]

    def aggregate_review(
        self,
        server_round: int,
        review_round: int,
        results: List[Tuple[ClientProxy, ReviewRes]],
        failures: List[Union[Tuple[ClientProxy, ReviewRes], BaseException]],
        parameters: Parameters,
        parameters_aggregated: List[Optional[Parameters]],
        metrics_aggregated: List[Dict[str, Scalar]],
    ) -> List[Tuple[Optional[Parameters], Dict[str, Scalar]]]:
        if not results:
            raise AggregateReviewException
        # Do not aggregate if there are failures and failures are not accepted
        if not self.accept_failures and failures:
            raise AggregateReviewException
        # Compute gamma
        gamma_numerator = sum(
            [
                parameters_to_ndarrays(review_res.parameters)[0]
                for _, review_res in results
            ]
        )
        gamma_denominator = sum(
            [
                parameters_to_ndarrays(review_res.parameters)[1]
                for _, review_res in results
            ]
        )
        gamma = np.linalg.inv(gamma_denominator) @ gamma_numerator
        gamma = gamma / (len(gamma))
        # Return candidates parameters along with gamma
        return [
            (params, gamma_i) for params, gamma_i in zip(parameters_aggregated, gamma)
        ]

    def aggregate_after_review(
        self,
        server_round: int,
        parameters: Parameters,
        parameters_aggregated: List[Optional[Parameters]],
        metrics_aggregated: List[Dict[str, Scalar]],
    ) -> Optional[Parameters]:
        # Update global model with candidated weighted by computed gamma
        model = deserialize_gradient_boosting_regressor(parameters.tensors[0])
        for params, gamma in zip(parameters_aggregated, metrics_aggregated):
            model.add_estimator(
                deserialize_decision_tree_regressor(params.tensors[0]), gamma
            )
        # Return the new serialized global model
        return Parameters(
            tensors=[serialize_gradient_boosting_regressor(model)], tensor_type="bytes"
        )

    def stop_review(
        self,
        server_round: int,
        review_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
        parameters_aggregated: List[Optional[Parameters]],
        metrics_aggregated: List[Dict[str, Scalar]],
    ) -> bool:
        # Always stop the review process after the first review round
        return True

    def initialize_parameters(
        self, client_manager: ClientManager
    ) -> Optional[Parameters]:
        model = FederatedGradientBoostingRegressor()
        return Parameters(
            tensors=[serialize_gradient_boosting_regressor(model)], tensor_type="bytes"
        )

    def evaluate(
        self, server_round: int, parameters: Parameters
    ) -> Optional[Tuple[float, Dict[str, Scalar]]]:
        if self.evaluate_fn is None:
            # No evaluation function provided
            return None
        eval_res = self.evaluate_fn(server_round, parameters, {})
        if eval_res is None:
            return None
        loss, metrics = eval_res
        return loss, metrics

# %%
# Setup of the federated learning simulation using PeerReviewFlower concurrent simulation


def client_fn(cid: str):
    cid = int(cid)
    trainset = (
        x_train.iloc[train_clusters == cid],
        y_train.iloc[train_clusters == cid],
    )
    testset = (x_test.iloc[test_clusters == cid], y_test.iloc[test_clusters == cid])
    return FedLSBTClient(cid, cp(trainset), cp(testset))


def evaluate_fn(
    server_round: int,
    parameters: Parameters,
    config: Dict[str, fl.common.Scalar],
) -> Optional[Tuple[float, Dict[str, fl.common.Scalar]]]:
    model = deserialize_gradient_boosting_regressor(parameters.tensors[0])
    y_pred = model.predict(x_test)
    loss = mean_squared_error(y_test, y_pred)
    return loss, {}


strategy = FederatedGradientBoostingStrategy(
    fraction_train=FRACTION_TRAIN,
    fraction_review=FRACTION_REVIEW,
    fraction_evaluate=FRACTION_EVAL,
    min_train_clients=int(NUM_CLIENTS * FRACTION_TRAIN),
    min_review_clients=int(NUM_CLIENTS * FRACTION_REVIEW),
    min_evaluate_clients=int(NUM_CLIENTS * FRACTION_EVAL),
    min_available_clients=NUM_CLIENTS,
    evaluate_fn=evaluate_fn,
)
server = PeerReviewServer(strategy=strategy)
hist = start_simulation(
    num_clients=NUM_CLIENTS,
    client_fn=client_fn,
    server=server,
    config=ServerConfig(num_rounds=NUM_ROUNDS),
    strategy=strategy,
)
# Out:
# WARNING flower 2023-05-25 22:45:58,411 | app.py:177 | Both server and strategy were provided, ignoring strategy
# WARNING:flower:Both server and strategy were provided, ignoring strategy
# INFO flower 2023-05-25 22:45:58,415 | app.py:69 | Starting Flower simulation, config: ServerConfig(num_rounds=50, round_timeout=None)
# INFO:flower:Starting Flower simulation, config: ServerConfig(num_rounds=50, round_timeout=None)
# INFO flower 2023-05-25 22:45:58,455 | server.py:126 | Initializing global parameters
# INFO:flower:Initializing global parameters
# INFO flower 2023-05-25 22:45:58,460 | server.py:409 | Using initial parameters provided by strategy
# INFO:flower:Using initial parameters provided by strategy
# INFO flower 2023-05-25 22:45:58,467 | server.py:129 | Evaluating initial parameters
# INFO:flower:Evaluating initial parameters
# INFO flower 2023-05-25 22:45:58,470 | server.py:132 | initial parameters (loss, other metrics): 4.603846047425844, {}
# INFO:flower:initial parameters (loss, other metrics): 4.603846047425844, {}
# INFO flower 2023-05-25 22:45:58,473 | server.py:71 | FL starting
# INFO:flower:FL starting
# DEBUG flower 2023-05-25 22:45:58,475 | server.py:264 | train_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:45:58,535 | server.py:279 | train_round 1 received 10 results and 0 failures
# DEBUG:flower:train_round 1 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:45:58,548 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:45:58,838 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:45:58,910 | server.py:190 | fit progress: (
# 	server_round: 1,
# 	centralized_loss: 3.7859888814007365,
# 	metrics: {},
# 	time_elapsed 0.43443799018859863
# )
# INFO:flower:fit progress: (
# 	server_round: 1,
# 	centralized_loss: 3.7859888814007365,
# 	metrics: {},
# 	time_elapsed 0.43443799018859863
# )
# INFO flower 2023-05-25 22:45:58,923 | server.py:163 | evaluate_round 1: no clients selected, cancel
# INFO:flower:evaluate_round 1: no clients selected, cancel
# DEBUG flower 2023-05-25 22:45:58,929 | server.py:264 | train_round 2: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:45:59,236 | server.py:279 | train_round 2 received 10 results and 0 failures
# DEBUG:flower:train_round 2 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:45:59,261 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:45:59,761 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:45:59,906 | server.py:190 | fit progress: (
# 	server_round: 2,
# 	centralized_loss: 3.263487066405834,
# 	metrics: {},
# 	time_elapsed 1.4303350448608398
# )
# INFO:flower:fit progress: (
# 	server_round: 2,
# 	centralized_loss: 3.263487066405834,
# 	metrics: {},
# 	time_elapsed 1.4303350448608398
# )
# INFO flower 2023-05-25 22:45:59,913 | server.py:163 | evaluate_round 2: no clients selected, cancel
# INFO:flower:evaluate_round 2: no clients selected, cancel
# DEBUG flower 2023-05-25 22:45:59,921 | server.py:264 | train_round 3: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 3: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:00,384 | server.py:279 | train_round 3 received 10 results and 0 failures
# DEBUG:flower:train_round 3 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:00,401 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:01,058 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:01,229 | server.py:190 | fit progress: (
# 	server_round: 3,
# 	centralized_loss: 2.667073044368749,
# 	metrics: {},
# 	time_elapsed 2.753278970718384
# )
# INFO:flower:fit progress: (
# 	server_round: 3,
# 	centralized_loss: 2.667073044368749,
# 	metrics: {},
# 	time_elapsed 2.753278970718384
# )
# INFO flower 2023-05-25 22:46:01,241 | server.py:163 | evaluate_round 3: no clients selected, cancel
# INFO:flower:evaluate_round 3: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:01,250 | server.py:264 | train_round 4: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 4: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:02,005 | server.py:279 | train_round 4 received 10 results and 0 failures
# DEBUG:flower:train_round 4 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:02,030 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:02,863 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:03,069 | server.py:190 | fit progress: (
# 	server_round: 4,
# 	centralized_loss: 2.2482165656171813,
# 	metrics: {},
# 	time_elapsed 4.593985080718994
# )
# INFO:flower:fit progress: (
# 	server_round: 4,
# 	centralized_loss: 2.2482165656171813,
# 	metrics: {},
# 	time_elapsed 4.593985080718994
# )
# INFO flower 2023-05-25 22:46:03,084 | server.py:163 | evaluate_round 4: no clients selected, cancel
# INFO:flower:evaluate_round 4: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:03,094 | server.py:264 | train_round 5: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 5: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:03,980 | server.py:279 | train_round 5 received 10 results and 0 failures
# DEBUG:flower:train_round 5 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:04,000 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:05,101 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:05,429 | server.py:190 | fit progress: (
# 	server_round: 5,
# 	centralized_loss: 1.9684505974414641,
# 	metrics: {},
# 	time_elapsed 6.953285455703735
# )
# INFO:flower:fit progress: (
# 	server_round: 5,
# 	centralized_loss: 1.9684505974414641,
# 	metrics: {},
# 	time_elapsed 6.953285455703735
# )
# INFO flower 2023-05-25 22:46:05,444 | server.py:163 | evaluate_round 5: no clients selected, cancel
# INFO:flower:evaluate_round 5: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:05,452 | server.py:264 | train_round 6: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 6: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:06,820 | server.py:279 | train_round 6 received 10 results and 0 failures
# DEBUG:flower:train_round 6 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:06,883 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:09,039 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:09,426 | server.py:190 | fit progress: (
# 	server_round: 6,
# 	centralized_loss: 1.6868889765007957,
# 	metrics: {},
# 	time_elapsed 10.951111078262329
# )
# INFO:flower:fit progress: (
# 	server_round: 6,
# 	centralized_loss: 1.6868889765007957,
# 	metrics: {},
# 	time_elapsed 10.951111078262329
# )
# INFO flower 2023-05-25 22:46:09,436 | server.py:163 | evaluate_round 6: no clients selected, cancel
# INFO:flower:evaluate_round 6: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:09,443 | server.py:264 | train_round 7: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 7: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:11,078 | server.py:279 | train_round 7 received 10 results and 0 failures
# DEBUG:flower:train_round 7 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:11,112 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:12,959 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:13,396 | server.py:190 | fit progress: (
# 	server_round: 7,
# 	centralized_loss: 1.4510263931541514,
# 	metrics: {},
# 	time_elapsed 14.920698881149292
# )
# INFO:flower:fit progress: (
# 	server_round: 7,
# 	centralized_loss: 1.4510263931541514,
# 	metrics: {},
# 	time_elapsed 14.920698881149292
# )
# INFO flower 2023-05-25 22:46:13,411 | server.py:163 | evaluate_round 7: no clients selected, cancel
# INFO:flower:evaluate_round 7: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:13,418 | server.py:264 | train_round 8: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 8: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:15,268 | server.py:279 | train_round 8 received 10 results and 0 failures
# DEBUG:flower:train_round 8 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:15,353 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:17,338 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:17,807 | server.py:190 | fit progress: (
# 	server_round: 8,
# 	centralized_loss: 1.255547201664644,
# 	metrics: {},
# 	time_elapsed 19.332064151763916
# )
# INFO:flower:fit progress: (
# 	server_round: 8,
# 	centralized_loss: 1.255547201664644,
# 	metrics: {},
# 	time_elapsed 19.332064151763916
# )
# INFO flower 2023-05-25 22:46:17,820 | server.py:163 | evaluate_round 8: no clients selected, cancel
# INFO:flower:evaluate_round 8: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:17,831 | server.py:264 | train_round 9: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 9: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:19,672 | server.py:279 | train_round 9 received 10 results and 0 failures
# DEBUG:flower:train_round 9 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:19,747 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:21,791 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:22,483 | server.py:190 | fit progress: (
# 	server_round: 9,
# 	centralized_loss: 1.117903147002311,
# 	metrics: {},
# 	time_elapsed 24.00792169570923
# )
# INFO:flower:fit progress: (
# 	server_round: 9,
# 	centralized_loss: 1.117903147002311,
# 	metrics: {},
# 	time_elapsed 24.00792169570923
# )
# INFO flower 2023-05-25 22:46:22,497 | server.py:163 | evaluate_round 9: no clients selected, cancel
# INFO:flower:evaluate_round 9: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:22,515 | server.py:264 | train_round 10: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 10: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:25,143 | server.py:279 | train_round 10 received 10 results and 0 failures
# DEBUG:flower:train_round 10 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:25,186 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:27,084 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:27,321 | server.py:190 | fit progress: (
# 	server_round: 10,
# 	centralized_loss: 0.977024659623505,
# 	metrics: {},
# 	time_elapsed 28.84586524963379
# )
# INFO:flower:fit progress: (
# 	server_round: 10,
# 	centralized_loss: 0.977024659623505,
# 	metrics: {},
# 	time_elapsed 28.84586524963379
# )
# INFO flower 2023-05-25 22:46:27,325 | server.py:163 | evaluate_round 10: no clients selected, cancel
# INFO:flower:evaluate_round 10: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:27,332 | server.py:264 | train_round 11: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 11: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:28,646 | server.py:279 | train_round 11 received 10 results and 0 failures
# DEBUG:flower:train_round 11 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:28,674 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:29,973 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:30,186 | server.py:190 | fit progress: (
# 	server_round: 11,
# 	centralized_loss: 0.9151659109645452,
# 	metrics: {},
# 	time_elapsed 31.71059799194336
# )
# INFO:flower:fit progress: (
# 	server_round: 11,
# 	centralized_loss: 0.9151659109645452,
# 	metrics: {},
# 	time_elapsed 31.71059799194336
# )
# INFO flower 2023-05-25 22:46:30,192 | server.py:163 | evaluate_round 11: no clients selected, cancel
# INFO:flower:evaluate_round 11: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:30,200 | server.py:264 | train_round 12: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 12: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:31,639 | server.py:279 | train_round 12 received 10 results and 0 failures
# DEBUG:flower:train_round 12 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:31,668 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:33,131 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:33,358 | server.py:190 | fit progress: (
# 	server_round: 12,
# 	centralized_loss: 0.8273509147371182,
# 	metrics: {},
# 	time_elapsed 34.882362365722656
# )
# INFO:flower:fit progress: (
# 	server_round: 12,
# 	centralized_loss: 0.8273509147371182,
# 	metrics: {},
# 	time_elapsed 34.882362365722656
# )
# INFO flower 2023-05-25 22:46:33,361 | server.py:163 | evaluate_round 12: no clients selected, cancel
# INFO:flower:evaluate_round 12: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:33,365 | server.py:264 | train_round 13: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 13: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:34,910 | server.py:279 | train_round 13 received 10 results and 0 failures
# DEBUG:flower:train_round 13 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:34,941 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:36,490 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:36,839 | server.py:190 | fit progress: (
# 	server_round: 13,
# 	centralized_loss: 0.7715843871952961,
# 	metrics: {},
# 	time_elapsed 38.36351728439331
# )
# INFO:flower:fit progress: (
# 	server_round: 13,
# 	centralized_loss: 0.7715843871952961,
# 	metrics: {},
# 	time_elapsed 38.36351728439331
# )
# INFO flower 2023-05-25 22:46:36,842 | server.py:163 | evaluate_round 13: no clients selected, cancel
# INFO:flower:evaluate_round 13: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:36,848 | server.py:264 | train_round 14: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 14: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:38,868 | server.py:279 | train_round 14 received 10 results and 0 failures
# DEBUG:flower:train_round 14 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:38,923 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:41,585 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:41,953 | server.py:190 | fit progress: (
# 	server_round: 14,
# 	centralized_loss: 0.6986672129823562,
# 	metrics: {},
# 	time_elapsed 43.47801876068115
# )
# INFO:flower:fit progress: (
# 	server_round: 14,
# 	centralized_loss: 0.6986672129823562,
# 	metrics: {},
# 	time_elapsed 43.47801876068115
# )
# INFO flower 2023-05-25 22:46:41,962 | server.py:163 | evaluate_round 14: no clients selected, cancel
# INFO:flower:evaluate_round 14: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:41,970 | server.py:264 | train_round 15: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 15: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:43,813 | server.py:279 | train_round 15 received 10 results and 0 failures
# DEBUG:flower:train_round 15 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:43,851 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:45,743 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:46,025 | server.py:190 | fit progress: (
# 	server_round: 15,
# 	centralized_loss: 0.6405656226525185,
# 	metrics: {},
# 	time_elapsed 47.550050497055054
# )
# INFO:flower:fit progress: (
# 	server_round: 15,
# 	centralized_loss: 0.6405656226525185,
# 	metrics: {},
# 	time_elapsed 47.550050497055054
# )
# INFO flower 2023-05-25 22:46:46,030 | server.py:163 | evaluate_round 15: no clients selected, cancel
# INFO:flower:evaluate_round 15: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:46,033 | server.py:264 | train_round 16: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 16: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:47,909 | server.py:279 | train_round 16 received 10 results and 0 failures
# DEBUG:flower:train_round 16 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:47,956 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:49,957 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:50,247 | server.py:190 | fit progress: (
# 	server_round: 16,
# 	centralized_loss: 0.5951612336128701,
# 	metrics: {},
# 	time_elapsed 51.771811723709106
# )
# INFO:flower:fit progress: (
# 	server_round: 16,
# 	centralized_loss: 0.5951612336128701,
# 	metrics: {},
# 	time_elapsed 51.771811723709106
# )
# INFO flower 2023-05-25 22:46:50,253 | server.py:163 | evaluate_round 16: no clients selected, cancel
# INFO:flower:evaluate_round 16: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:50,257 | server.py:264 | train_round 17: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 17: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:52,320 | server.py:279 | train_round 17 received 10 results and 0 failures
# DEBUG:flower:train_round 17 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:52,379 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:55,473 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:46:55,966 | server.py:190 | fit progress: (
# 	server_round: 17,
# 	centralized_loss: 0.5598008373799863,
# 	metrics: {},
# 	time_elapsed 57.49070596694946
# )
# INFO:flower:fit progress: (
# 	server_round: 17,
# 	centralized_loss: 0.5598008373799863,
# 	metrics: {},
# 	time_elapsed 57.49070596694946
# )
# INFO flower 2023-05-25 22:46:55,975 | server.py:163 | evaluate_round 17: no clients selected, cancel
# INFO:flower:evaluate_round 17: no clients selected, cancel
# DEBUG flower 2023-05-25 22:46:55,982 | server.py:264 | train_round 18: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 18: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:46:58,439 | server.py:279 | train_round 18 received 10 results and 0 failures
# DEBUG:flower:train_round 18 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:46:58,479 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:00,807 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:47:01,111 | server.py:190 | fit progress: (
# 	server_round: 18,
# 	centralized_loss: 0.5299414024536252,
# 	metrics: {},
# 	time_elapsed 62.63532304763794
# )
# INFO:flower:fit progress: (
# 	server_round: 18,
# 	centralized_loss: 0.5299414024536252,
# 	metrics: {},
# 	time_elapsed 62.63532304763794
# )
# INFO flower 2023-05-25 22:47:01,115 | server.py:163 | evaluate_round 18: no clients selected, cancel
# INFO:flower:evaluate_round 18: no clients selected, cancel
# DEBUG flower 2023-05-25 22:47:01,119 | server.py:264 | train_round 19: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 19: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:03,399 | server.py:279 | train_round 19 received 10 results and 0 failures
# DEBUG:flower:train_round 19 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:47:03,443 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:05,824 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:47:06,152 | server.py:190 | fit progress: (
# 	server_round: 19,
# 	centralized_loss: 0.5134287140836535,
# 	metrics: {},
# 	time_elapsed 67.67708349227905
# )
# INFO:flower:fit progress: (
# 	server_round: 19,
# 	centralized_loss: 0.5134287140836535,
# 	metrics: {},
# 	time_elapsed 67.67708349227905
# )
# INFO flower 2023-05-25 22:47:06,158 | server.py:163 | evaluate_round 19: no clients selected, cancel
# INFO:flower:evaluate_round 19: no clients selected, cancel
# DEBUG flower 2023-05-25 22:47:06,162 | server.py:264 | train_round 20: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 20: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:09,208 | server.py:279 | train_round 20 received 10 results and 0 failures
# DEBUG:flower:train_round 20 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:47:09,399 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:12,721 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:47:13,061 | server.py:190 | fit progress: (
# 	server_round: 20,
# 	centralized_loss: 0.4969382461813473,
# 	metrics: {},
# 	time_elapsed 74.58604645729065
# )
# INFO:flower:fit progress: (
# 	server_round: 20,
# 	centralized_loss: 0.4969382461813473,
# 	metrics: {},
# 	time_elapsed 74.58604645729065
# )
# INFO flower 2023-05-25 22:47:13,069 | server.py:163 | evaluate_round 20: no clients selected, cancel
# INFO:flower:evaluate_round 20: no clients selected, cancel
# DEBUG flower 2023-05-25 22:47:13,073 | server.py:264 | train_round 21: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 21: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:15,936 | server.py:279 | train_round 21 received 10 results and 0 failures
# DEBUG:flower:train_round 21 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:47:15,984 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:18,567 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:47:19,020 | server.py:190 | fit progress: (
# 	server_round: 21,
# 	centralized_loss: 0.47507857828559885,
# 	metrics: {},
# 	time_elapsed 80.54428744316101
# )
# INFO:flower:fit progress: (
# 	server_round: 21,
# 	centralized_loss: 0.47507857828559885,
# 	metrics: {},
# 	time_elapsed 80.54428744316101
# )
# INFO flower 2023-05-25 22:47:19,023 | server.py:163 | evaluate_round 21: no clients selected, cancel
# INFO:flower:evaluate_round 21: no clients selected, cancel
# DEBUG flower 2023-05-25 22:47:19,027 | server.py:264 | train_round 22: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 22: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:21,684 | server.py:279 | train_round 22 received 10 results and 0 failures
# DEBUG:flower:train_round 22 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:47:21,762 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:25,818 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:47:26,391 | server.py:190 | fit progress: (
# 	server_round: 22,
# 	centralized_loss: 0.4566143027021197,
# 	metrics: {},
# 	time_elapsed 87.91558885574341
# )
# INFO:flower:fit progress: (
# 	server_round: 22,
# 	centralized_loss: 0.4566143027021197,
# 	metrics: {},
# 	time_elapsed 87.91558885574341
# )
# INFO flower 2023-05-25 22:47:26,397 | server.py:163 | evaluate_round 22: no clients selected, cancel
# INFO:flower:evaluate_round 22: no clients selected, cancel
# DEBUG flower 2023-05-25 22:47:26,401 | server.py:264 | train_round 23: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 23: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:29,299 | server.py:279 | train_round 23 received 10 results and 0 failures
# DEBUG:flower:train_round 23 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:47:29,346 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:32,192 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:47:32,596 | server.py:190 | fit progress: (
# 	server_round: 23,
# 	centralized_loss: 0.4355415981769582,
# 	metrics: {},
# 	time_elapsed 94.12096858024597
# )
# INFO:flower:fit progress: (
# 	server_round: 23,
# 	centralized_loss: 0.4355415981769582,
# 	metrics: {},
# 	time_elapsed 94.12096858024597
# )
# INFO flower 2023-05-25 22:47:32,601 | server.py:163 | evaluate_round 23: no clients selected, cancel
# INFO:flower:evaluate_round 23: no clients selected, cancel
# DEBUG flower 2023-05-25 22:47:32,605 | server.py:264 | train_round 24: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 24: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:35,572 | server.py:279 | train_round 24 received 10 results and 0 failures
# DEBUG:flower:train_round 24 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:47:35,628 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:39,420 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:47:40,016 | server.py:190 | fit progress: (
# 	server_round: 24,
# 	centralized_loss: 0.42883833121783915,
# 	metrics: {},
# 	time_elapsed 101.5402283668518
# )
# INFO:flower:fit progress: (
# 	server_round: 24,
# 	centralized_loss: 0.42883833121783915,
# 	metrics: {},
# 	time_elapsed 101.5402283668518
# )
# INFO flower 2023-05-25 22:47:40,025 | server.py:163 | evaluate_round 24: no clients selected, cancel
# INFO:flower:evaluate_round 24: no clients selected, cancel
# DEBUG flower 2023-05-25 22:47:40,032 | server.py:264 | train_round 25: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 25: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:43,571 | server.py:279 | train_round 25 received 10 results and 0 failures
# DEBUG:flower:train_round 25 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:47:43,622 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:46,699 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:47:47,185 | server.py:190 | fit progress: (
# 	server_round: 25,
# 	centralized_loss: 0.4343145929355691,
# 	metrics: {},
# 	time_elapsed 108.70976448059082
# )
# INFO:flower:fit progress: (
# 	server_round: 25,
# 	centralized_loss: 0.4343145929355691,
# 	metrics: {},
# 	time_elapsed 108.70976448059082
# )
# INFO flower 2023-05-25 22:47:47,193 | server.py:163 | evaluate_round 25: no clients selected, cancel
# INFO:flower:evaluate_round 25: no clients selected, cancel
# DEBUG flower 2023-05-25 22:47:47,197 | server.py:264 | train_round 26: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 26: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:50,211 | server.py:279 | train_round 26 received 10 results and 0 failures
# DEBUG:flower:train_round 26 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:47:50,265 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:54,336 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:47:54,980 | server.py:190 | fit progress: (
# 	server_round: 26,
# 	centralized_loss: 0.4288974371408729,
# 	metrics: {},
# 	time_elapsed 116.50493383407593
# )
# INFO:flower:fit progress: (
# 	server_round: 26,
# 	centralized_loss: 0.4288974371408729,
# 	metrics: {},
# 	time_elapsed 116.50493383407593
# )
# INFO flower 2023-05-25 22:47:54,987 | server.py:163 | evaluate_round 26: no clients selected, cancel
# INFO:flower:evaluate_round 26: no clients selected, cancel
# DEBUG flower 2023-05-25 22:47:54,993 | server.py:264 | train_round 27: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 27: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:47:58,643 | server.py:279 | train_round 27 received 10 results and 0 failures
# DEBUG:flower:train_round 27 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:47:58,797 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:02,073 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:48:02,983 | server.py:190 | fit progress: (
# 	server_round: 27,
# 	centralized_loss: 0.4193286644502966,
# 	metrics: {},
# 	time_elapsed 124.5075786113739
# )
# INFO:flower:fit progress: (
# 	server_round: 27,
# 	centralized_loss: 0.4193286644502966,
# 	metrics: {},
# 	time_elapsed 124.5075786113739
# )
# INFO flower 2023-05-25 22:48:02,988 | server.py:163 | evaluate_round 27: no clients selected, cancel
# INFO:flower:evaluate_round 27: no clients selected, cancel
# DEBUG flower 2023-05-25 22:48:02,996 | server.py:264 | train_round 28: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 28: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:06,357 | server.py:279 | train_round 28 received 10 results and 0 failures
# DEBUG:flower:train_round 28 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:48:06,454 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:11,532 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:48:12,000 | server.py:190 | fit progress: (
# 	server_round: 28,
# 	centralized_loss: 0.4109078129674607,
# 	metrics: {},
# 	time_elapsed 133.52441596984863
# )
# INFO:flower:fit progress: (
# 	server_round: 28,
# 	centralized_loss: 0.4109078129674607,
# 	metrics: {},
# 	time_elapsed 133.52441596984863
# )
# INFO flower 2023-05-25 22:48:12,006 | server.py:163 | evaluate_round 28: no clients selected, cancel
# INFO:flower:evaluate_round 28: no clients selected, cancel
# DEBUG flower 2023-05-25 22:48:12,014 | server.py:264 | train_round 29: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 29: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:15,534 | server.py:279 | train_round 29 received 10 results and 0 failures
# DEBUG:flower:train_round 29 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:48:15,592 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:19,261 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:48:19,739 | server.py:190 | fit progress: (
# 	server_round: 29,
# 	centralized_loss: 0.4053409848412823,
# 	metrics: {},
# 	time_elapsed 141.26347064971924
# )
# INFO:flower:fit progress: (
# 	server_round: 29,
# 	centralized_loss: 0.4053409848412823,
# 	metrics: {},
# 	time_elapsed 141.26347064971924
# )
# INFO flower 2023-05-25 22:48:19,746 | server.py:163 | evaluate_round 29: no clients selected, cancel
# INFO:flower:evaluate_round 29: no clients selected, cancel
# DEBUG flower 2023-05-25 22:48:19,751 | server.py:264 | train_round 30: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 30: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:24,294 | server.py:279 | train_round 30 received 10 results and 0 failures
# DEBUG:flower:train_round 30 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:48:24,409 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:28,639 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:48:29,190 | server.py:190 | fit progress: (
# 	server_round: 30,
# 	centralized_loss: 0.39994927624267307,
# 	metrics: {},
# 	time_elapsed 150.7144637107849
# )
# INFO:flower:fit progress: (
# 	server_round: 30,
# 	centralized_loss: 0.39994927624267307,
# 	metrics: {},
# 	time_elapsed 150.7144637107849
# )
# INFO flower 2023-05-25 22:48:29,194 | server.py:163 | evaluate_round 30: no clients selected, cancel
# INFO:flower:evaluate_round 30: no clients selected, cancel
# DEBUG flower 2023-05-25 22:48:29,198 | server.py:264 | train_round 31: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 31: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:33,745 | server.py:279 | train_round 31 received 10 results and 0 failures
# DEBUG:flower:train_round 31 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:48:33,811 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:38,257 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:48:39,112 | server.py:190 | fit progress: (
# 	server_round: 31,
# 	centralized_loss: 0.3953107662349282,
# 	metrics: {},
# 	time_elapsed 160.63667249679565
# )
# INFO:flower:fit progress: (
# 	server_round: 31,
# 	centralized_loss: 0.3953107662349282,
# 	metrics: {},
# 	time_elapsed 160.63667249679565
# )
# INFO flower 2023-05-25 22:48:39,117 | server.py:163 | evaluate_round 31: no clients selected, cancel
# INFO:flower:evaluate_round 31: no clients selected, cancel
# DEBUG flower 2023-05-25 22:48:39,122 | server.py:264 | train_round 32: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 32: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:43,647 | server.py:279 | train_round 32 received 10 results and 0 failures
# DEBUG:flower:train_round 32 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:48:43,713 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:48,872 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:48:49,700 | server.py:190 | fit progress: (
# 	server_round: 32,
# 	centralized_loss: 0.3948521544706188,
# 	metrics: {},
# 	time_elapsed 171.224458694458
# )
# INFO:flower:fit progress: (
# 	server_round: 32,
# 	centralized_loss: 0.3948521544706188,
# 	metrics: {},
# 	time_elapsed 171.224458694458
# )
# INFO flower 2023-05-25 22:48:49,704 | server.py:163 | evaluate_round 32: no clients selected, cancel
# INFO:flower:evaluate_round 32: no clients selected, cancel
# DEBUG flower 2023-05-25 22:48:49,708 | server.py:264 | train_round 33: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 33: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:55,042 | server.py:279 | train_round 33 received 10 results and 0 failures
# DEBUG:flower:train_round 33 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:48:55,152 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:48:59,420 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:49:00,038 | server.py:190 | fit progress: (
# 	server_round: 33,
# 	centralized_loss: 0.38978370418478175,
# 	metrics: {},
# 	time_elapsed 181.56304097175598
# )
# INFO:flower:fit progress: (
# 	server_round: 33,
# 	centralized_loss: 0.38978370418478175,
# 	metrics: {},
# 	time_elapsed 181.56304097175598
# )
# INFO flower 2023-05-25 22:49:00,045 | server.py:163 | evaluate_round 33: no clients selected, cancel
# INFO:flower:evaluate_round 33: no clients selected, cancel
# DEBUG flower 2023-05-25 22:49:00,049 | server.py:264 | train_round 34: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 34: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:04,019 | server.py:279 | train_round 34 received 10 results and 0 failures
# DEBUG:flower:train_round 34 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:49:04,089 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:09,524 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:49:10,427 | server.py:190 | fit progress: (
# 	server_round: 34,
# 	centralized_loss: 0.39082994560353285,
# 	metrics: {},
# 	time_elapsed 191.95158338546753
# )
# INFO:flower:fit progress: (
# 	server_round: 34,
# 	centralized_loss: 0.39082994560353285,
# 	metrics: {},
# 	time_elapsed 191.95158338546753
# )
# INFO flower 2023-05-25 22:49:10,431 | server.py:163 | evaluate_round 34: no clients selected, cancel
# INFO:flower:evaluate_round 34: no clients selected, cancel
# DEBUG flower 2023-05-25 22:49:10,438 | server.py:264 | train_round 35: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 35: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:14,606 | server.py:279 | train_round 35 received 10 results and 0 failures
# DEBUG:flower:train_round 35 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:49:14,773 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:19,117 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:49:19,675 | server.py:190 | fit progress: (
# 	server_round: 35,
# 	centralized_loss: 0.388854103564701,
# 	metrics: {},
# 	time_elapsed 201.20022082328796
# )
# INFO:flower:fit progress: (
# 	server_round: 35,
# 	centralized_loss: 0.388854103564701,
# 	metrics: {},
# 	time_elapsed 201.20022082328796
# )
# INFO flower 2023-05-25 22:49:19,681 | server.py:163 | evaluate_round 35: no clients selected, cancel
# INFO:flower:evaluate_round 35: no clients selected, cancel
# DEBUG flower 2023-05-25 22:49:19,685 | server.py:264 | train_round 36: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 36: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:25,505 | server.py:279 | train_round 36 received 10 results and 0 failures
# DEBUG:flower:train_round 36 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:49:25,675 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:30,064 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:49:30,716 | server.py:190 | fit progress: (
# 	server_round: 36,
# 	centralized_loss: 0.3825171582405247,
# 	metrics: {},
# 	time_elapsed 212.24039363861084
# )
# INFO:flower:fit progress: (
# 	server_round: 36,
# 	centralized_loss: 0.3825171582405247,
# 	metrics: {},
# 	time_elapsed 212.24039363861084
# )
# INFO flower 2023-05-25 22:49:30,723 | server.py:163 | evaluate_round 36: no clients selected, cancel
# INFO:flower:evaluate_round 36: no clients selected, cancel
# DEBUG flower 2023-05-25 22:49:30,730 | server.py:264 | train_round 37: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 37: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:35,279 | server.py:279 | train_round 37 received 10 results and 0 failures
# DEBUG:flower:train_round 37 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:49:35,406 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:41,410 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:49:42,085 | server.py:190 | fit progress: (
# 	server_round: 37,
# 	centralized_loss: 0.385251558873638,
# 	metrics: {},
# 	time_elapsed 223.60957026481628
# )
# INFO:flower:fit progress: (
# 	server_round: 37,
# 	centralized_loss: 0.385251558873638,
# 	metrics: {},
# 	time_elapsed 223.60957026481628
# )
# INFO flower 2023-05-25 22:49:42,088 | server.py:163 | evaluate_round 37: no clients selected, cancel
# INFO:flower:evaluate_round 37: no clients selected, cancel
# DEBUG flower 2023-05-25 22:49:42,092 | server.py:264 | train_round 38: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 38: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:46,687 | server.py:279 | train_round 38 received 10 results and 0 failures
# DEBUG:flower:train_round 38 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:49:46,760 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:52,466 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:49:53,508 | server.py:190 | fit progress: (
# 	server_round: 38,
# 	centralized_loss: 0.3815942472349897,
# 	metrics: {},
# 	time_elapsed 235.032958984375
# )
# INFO:flower:fit progress: (
# 	server_round: 38,
# 	centralized_loss: 0.3815942472349897,
# 	metrics: {},
# 	time_elapsed 235.032958984375
# )
# INFO flower 2023-05-25 22:49:53,517 | server.py:163 | evaluate_round 38: no clients selected, cancel
# INFO:flower:evaluate_round 38: no clients selected, cancel
# DEBUG flower 2023-05-25 22:49:53,521 | server.py:264 | train_round 39: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 39: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:49:58,570 | server.py:279 | train_round 39 received 10 results and 0 failures
# DEBUG:flower:train_round 39 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:49:58,653 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:50:03,487 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:50:04,166 | server.py:190 | fit progress: (
# 	server_round: 39,
# 	centralized_loss: 0.37722549776235165,
# 	metrics: {},
# 	time_elapsed 245.69041776657104
# )
# INFO:flower:fit progress: (
# 	server_round: 39,
# 	centralized_loss: 0.37722549776235165,
# 	metrics: {},
# 	time_elapsed 245.69041776657104
# )
# INFO flower 2023-05-25 22:50:04,170 | server.py:163 | evaluate_round 39: no clients selected, cancel
# INFO:flower:evaluate_round 39: no clients selected, cancel
# DEBUG flower 2023-05-25 22:50:04,174 | server.py:264 | train_round 40: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 40: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:50:10,403 | server.py:279 | train_round 40 received 10 results and 0 failures
# DEBUG:flower:train_round 40 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:50:10,578 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:50:15,487 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:50:16,106 | server.py:190 | fit progress: (
# 	server_round: 40,
# 	centralized_loss: 0.37058561549962493,
# 	metrics: {},
# 	time_elapsed 257.63027024269104
# )
# INFO:flower:fit progress: (
# 	server_round: 40,
# 	centralized_loss: 0.37058561549962493,
# 	metrics: {},
# 	time_elapsed 257.63027024269104
# )
# INFO flower 2023-05-25 22:50:16,110 | server.py:163 | evaluate_round 40: no clients selected, cancel
# INFO:flower:evaluate_round 40: no clients selected, cancel
# DEBUG flower 2023-05-25 22:50:16,114 | server.py:264 | train_round 41: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 41: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:50:21,767 | server.py:279 | train_round 41 received 10 results and 0 failures
# DEBUG:flower:train_round 41 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:50:21,916 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:50:27,756 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:50:28,485 | server.py:190 | fit progress: (
# 	server_round: 41,
# 	centralized_loss: 0.37378716991337585,
# 	metrics: {},
# 	time_elapsed 270.0097608566284
# )
# INFO:flower:fit progress: (
# 	server_round: 41,
# 	centralized_loss: 0.37378716991337585,
# 	metrics: {},
# 	time_elapsed 270.0097608566284
# )
# INFO flower 2023-05-25 22:50:28,493 | server.py:163 | evaluate_round 41: no clients selected, cancel
# INFO:flower:evaluate_round 41: no clients selected, cancel
# DEBUG flower 2023-05-25 22:50:28,497 | server.py:264 | train_round 42: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 42: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:50:33,559 | server.py:279 | train_round 42 received 10 results and 0 failures
# DEBUG:flower:train_round 42 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:50:33,645 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:50:40,459 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:50:41,120 | server.py:190 | fit progress: (
# 	server_round: 42,
# 	centralized_loss: 0.3651799673778926,
# 	metrics: {},
# 	time_elapsed 282.6447341442108
# )
# INFO:flower:fit progress: (
# 	server_round: 42,
# 	centralized_loss: 0.3651799673778926,
# 	metrics: {},
# 	time_elapsed 282.6447341442108
# )
# INFO flower 2023-05-25 22:50:41,125 | server.py:163 | evaluate_round 42: no clients selected, cancel
# INFO:flower:evaluate_round 42: no clients selected, cancel
# DEBUG flower 2023-05-25 22:50:41,131 | server.py:264 | train_round 43: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 43: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:50:46,501 | server.py:279 | train_round 43 received 10 results and 0 failures
# DEBUG:flower:train_round 43 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:50:46,588 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:50:53,317 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:50:54,156 | server.py:190 | fit progress: (
# 	server_round: 43,
# 	centralized_loss: 0.3622472699229977,
# 	metrics: {},
# 	time_elapsed 295.6802988052368
# )
# INFO:flower:fit progress: (
# 	server_round: 43,
# 	centralized_loss: 0.3622472699229977,
# 	metrics: {},
# 	time_elapsed 295.6802988052368
# )
# INFO flower 2023-05-25 22:50:54,165 | server.py:163 | evaluate_round 43: no clients selected, cancel
# INFO:flower:evaluate_round 43: no clients selected, cancel
# DEBUG flower 2023-05-25 22:50:54,172 | server.py:264 | train_round 44: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 44: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:50:59,476 | server.py:279 | train_round 44 received 10 results and 0 failures
# DEBUG:flower:train_round 44 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:50:59,656 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:51:05,743 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:51:06,948 | server.py:190 | fit progress: (
# 	server_round: 44,
# 	centralized_loss: 0.3612798141195908,
# 	metrics: {},
# 	time_elapsed 308.4723153114319
# )
# INFO:flower:fit progress: (
# 	server_round: 44,
# 	centralized_loss: 0.3612798141195908,
# 	metrics: {},
# 	time_elapsed 308.4723153114319
# )
# INFO flower 2023-05-25 22:51:06,957 | server.py:163 | evaluate_round 44: no clients selected, cancel
# INFO:flower:evaluate_round 44: no clients selected, cancel
# DEBUG flower 2023-05-25 22:51:06,965 | server.py:264 | train_round 45: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 45: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:51:12,783 | server.py:279 | train_round 45 received 10 results and 0 failures
# DEBUG:flower:train_round 45 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:51:12,974 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:51:19,422 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:51:21,104 | server.py:190 | fit progress: (
# 	server_round: 45,
# 	centralized_loss: 0.35809545857446035,
# 	metrics: {},
# 	time_elapsed 322.62904167175293
# )
# INFO:flower:fit progress: (
# 	server_round: 45,
# 	centralized_loss: 0.35809545857446035,
# 	metrics: {},
# 	time_elapsed 322.62904167175293
# )
# INFO flower 2023-05-25 22:51:21,109 | server.py:163 | evaluate_round 45: no clients selected, cancel
# INFO:flower:evaluate_round 45: no clients selected, cancel
# DEBUG flower 2023-05-25 22:51:21,112 | server.py:264 | train_round 46: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 46: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:51:28,278 | server.py:279 | train_round 46 received 10 results and 0 failures
# DEBUG:flower:train_round 46 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:51:28,475 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:51:34,282 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:51:35,074 | server.py:190 | fit progress: (
# 	server_round: 46,
# 	centralized_loss: 0.35314702925979913,
# 	metrics: {},
# 	time_elapsed 336.5985219478607
# )
# INFO:flower:fit progress: (
# 	server_round: 46,
# 	centralized_loss: 0.35314702925979913,
# 	metrics: {},
# 	time_elapsed 336.5985219478607
# )
# INFO flower 2023-05-25 22:51:35,104 | server.py:163 | evaluate_round 46: no clients selected, cancel
# INFO:flower:evaluate_round 46: no clients selected, cancel
# DEBUG flower 2023-05-25 22:51:35,115 | server.py:264 | train_round 47: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 47: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:51:42,924 | server.py:279 | train_round 47 received 10 results and 0 failures
# DEBUG:flower:train_round 47 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:51:43,112 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:51:49,213 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:51:49,959 | server.py:190 | fit progress: (
# 	server_round: 47,
# 	centralized_loss: 0.3512429173252924,
# 	metrics: {},
# 	time_elapsed 351.4837486743927
# )
# INFO:flower:fit progress: (
# 	server_round: 47,
# 	centralized_loss: 0.3512429173252924,
# 	metrics: {},
# 	time_elapsed 351.4837486743927
# )
# INFO flower 2023-05-25 22:51:49,965 | server.py:163 | evaluate_round 47: no clients selected, cancel
# INFO:flower:evaluate_round 47: no clients selected, cancel
# DEBUG flower 2023-05-25 22:51:49,968 | server.py:264 | train_round 48: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 48: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:51:57,430 | server.py:279 | train_round 48 received 10 results and 0 failures
# DEBUG:flower:train_round 48 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:51:57,524 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:52:03,676 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:52:04,507 | server.py:190 | fit progress: (
# 	server_round: 48,
# 	centralized_loss: 0.3491657295514029,
# 	metrics: {},
# 	time_elapsed 366.0316197872162
# )
# INFO:flower:fit progress: (
# 	server_round: 48,
# 	centralized_loss: 0.3491657295514029,
# 	metrics: {},
# 	time_elapsed 366.0316197872162
# )
# INFO flower 2023-05-25 22:52:04,512 | server.py:163 | evaluate_round 48: no clients selected, cancel
# INFO:flower:evaluate_round 48: no clients selected, cancel
# DEBUG flower 2023-05-25 22:52:04,516 | server.py:264 | train_round 49: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 49: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:52:11,918 | server.py:279 | train_round 49 received 10 results and 0 failures
# DEBUG:flower:train_round 49 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:52:12,112 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:52:18,245 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:52:19,079 | server.py:190 | fit progress: (
# 	server_round: 49,
# 	centralized_loss: 0.34506428461007754,
# 	metrics: {},
# 	time_elapsed 380.60393595695496
# )
# INFO:flower:fit progress: (
# 	server_round: 49,
# 	centralized_loss: 0.34506428461007754,
# 	metrics: {},
# 	time_elapsed 380.60393595695496
# )
# INFO flower 2023-05-25 22:52:19,084 | server.py:163 | evaluate_round 49: no clients selected, cancel
# INFO:flower:evaluate_round 49: no clients selected, cancel
# DEBUG flower 2023-05-25 22:52:19,094 | server.py:264 | train_round 50: strategy sampled 10 clients (out of 30)
# DEBUG:flower:train_round 50: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:52:26,563 | server.py:279 | train_round 50 received 10 results and 0 failures
# DEBUG:flower:train_round 50 received 10 results and 0 failures
# DEBUG flower 2023-05-25 22:52:26,660 | server.py:356 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG:flower:review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2023-05-25 22:52:32,770 | server.py:371 | review_round 1 received 10 results and 0 failures
# DEBUG:flower:review_round 1 received 10 results and 0 failures
# INFO flower 2023-05-25 22:52:33,625 | server.py:190 | fit progress: (
# 	server_round: 50,
# 	centralized_loss: 0.34508813663975063,
# 	metrics: {},
# 	time_elapsed 395.150155544281
# )
# INFO:flower:fit progress: (
# 	server_round: 50,
# 	centralized_loss: 0.34508813663975063,
# 	metrics: {},
# 	time_elapsed 395.150155544281
# )
# INFO flower 2023-05-25 22:52:33,632 | server.py:163 | evaluate_round 50: no clients selected, cancel
# INFO:flower:evaluate_round 50: no clients selected, cancel
# INFO flower 2023-05-25 22:52:33,638 | server.py:120 | FL finished in 395.16271328926086
# INFO:flower:FL finished in 395.16271328926086
# INFO flower 2023-05-25 22:52:33,642 | app.py:192 | app_fit: losses_distributed []
# INFO:flower:app_fit: losses_distributed []
# INFO flower 2023-05-25 22:52:33,643 | app.py:193 | app_fit: metrics_distributed {}
# INFO:flower:app_fit: metrics_distributed {}
# INFO flower 2023-05-25 22:52:33,646 | app.py:194 | app_fit: losses_centralized [(0, 4.603846047425844), (1, 3.7859888814007365), (2, 3.263487066405834), (3, 2.667073044368749), (4, 2.2482165656171813), (5, 1.9684505974414641), (6, 1.6868889765007957), (7, 1.4510263931541514), (8, 1.255547201664644), (9, 1.117903147002311), (10, 0.977024659623505), (11, 0.9151659109645452), (12, 0.8273509147371182), (13, 0.7715843871952961), (14, 0.6986672129823562), (15, 0.6405656226525185), (16, 0.5951612336128701), (17, 0.5598008373799863), (18, 0.5299414024536252), (19, 0.5134287140836535), (20, 0.4969382461813473), (21, 0.47507857828559885), (22, 0.4566143027021197), (23, 0.4355415981769582), (24, 0.42883833121783915), (25, 0.4343145929355691), (26, 0.4288974371408729), (27, 0.4193286644502966), (28, 0.4109078129674607), (29, 0.4053409848412823), (30, 0.39994927624267307), (31, 0.3953107662349282), (32, 0.3948521544706188), (33, 0.38978370418478175), (34, 0.39082994560353285), (35, 0.388854103564701), (36, 0.3825171582405247), (37, 0.385251558873638), (38, 0.3815942472349897), (39, 0.37722549776235165), (40, 0.37058561549962493), (41, 0.37378716991337585), (42, 0.3651799673778926), (43, 0.3622472699229977), (44, 0.3612798141195908), (45, 0.35809545857446035), (46, 0.35314702925979913), (47, 0.3512429173252924), (48, 0.3491657295514029), (49, 0.34506428461007754), (50, 0.34508813663975063)]
# INFO:flower:app_fit: losses_centralized [(0, 4.603846047425844), (1, 3.7859888814007365), (2, 3.263487066405834), (3, 2.667073044368749), (4, 2.2482165656171813), (5, 1.9684505974414641), (6, 1.6868889765007957), (7, 1.4510263931541514), (8, 1.255547201664644), (9, 1.117903147002311), (10, 0.977024659623505), (11, 0.9151659109645452), (12, 0.8273509147371182), (13, 0.7715843871952961), (14, 0.6986672129823562), (15, 0.6405656226525185), (16, 0.5951612336128701), (17, 0.5598008373799863), (18, 0.5299414024536252), (19, 0.5134287140836535), (20, 0.4969382461813473), (21, 0.47507857828559885), (22, 0.4566143027021197), (23, 0.4355415981769582), (24, 0.42883833121783915), (25, 0.4343145929355691), (26, 0.4288974371408729), (27, 0.4193286644502966), (28, 0.4109078129674607), (29, 0.4053409848412823), (30, 0.39994927624267307), (31, 0.3953107662349282), (32, 0.3948521544706188), (33, 0.38978370418478175), (34, 0.39082994560353285), (35, 0.388854103564701), (36, 0.3825171582405247), (37, 0.385251558873638), (38, 0.3815942472349897), (39, 0.37722549776235165), (40, 0.37058561549962493), (41, 0.37378716991337585), (42, 0.3651799673778926), (43, 0.3622472699229977), (44, 0.3612798141195908), (45, 0.35809545857446035), (46, 0.35314702925979913), (47, 0.3512429173252924), (48, 0.3491657295514029), (49, 0.34506428461007754), (50, 0.34508813663975063)]
# INFO flower 2023-05-25 22:52:33,653 | app.py:195 | app_fit: metrics_centralized {}
# INFO:flower:app_fit: metrics_centralized {}

# %%
# Get trained FedLSBT model and test performances on test data
model = deserialize_gradient_boosting_regressor(server.parameters.tensors[0])
y_pred = model.predict(x_test)
print(f"r2: {r2_score(y_test, y_pred)}")
print(f"mse: {mean_squared_error(y_test, y_pred)}")
# Out:
# r2: 0.6322884522626486
# mse: 0.34508813663975063

# %%
# Plot model losses during training and trees coefficients
plt.plot([l[1] for l in hist.losses_centralized])
plt.plot(model.gammas_[::10])
sum(model.gammas_) / len(model.gammas_)
# Out:
# 0.014852958758749807
