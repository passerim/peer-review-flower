# %%
# !pip install git+https://github.com/passerim/peer-reviewed-flower.git

# %%
# import prflwr to use it in the notebook
import os; os.chdir("../.."); import prflwr; os.chdir("experiments/fedlsbt")

# %%
import json
from copy import deepcopy as cp
from typing import Any, Dict, List, Optional, Tuple, Union

import flwr as fl
import matplotlib.pyplot as plt
import numpy as np
from flwr.common import (
    Code,
    EvaluateIns,
    EvaluateRes,
    FitIns,
    FitRes,
    Parameters,
    Scalar,
    Status,
    ndarrays_to_parameters,
    parameters_to_ndarrays,
)
from flwr.server import ClientManager, ServerConfig, SimpleClientManager
from flwr.server.client_proxy import ClientProxy
from overrides import overrides
from sklearn.cluster import KMeans
from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.tree._tree import Tree

from prflwr.peer_review import (
    PeerReviewClient,
    PeerReviewServer,
    ReviewIns,
    ReviewRes,
    TrainIns,
    TrainRes,
)
from prflwr.peer_review.strategy import (
    AggregateReviewException,
    AggregateTrainException,
    PeerReviewedFedAvg,
)
from prflwr.simulation import start_simulation

# %%
# Training configurations
NUM_CLIENTS = 30
FRACTION_FIT = 1 / 3
FRACTION_REVIEW = 1 / 3
FRACTION_EVAL = 0
NUM_ROUNDS = 50

# Model hyperparameter
MAX_LEAVES = 8

# Useful constants
OK_STATUS = Status(Code.OK, "")

# %%
# Load data
DATA_HOME = "./data"
data_x, data_y = fetch_california_housing(
    data_home=DATA_HOME, return_X_y=True, as_frame=True
)
x_train, x_test, y_train, y_test = train_test_split(
    data_x, data_y, test_size=0.2, shuffle=True
)

# %%
x_train.head(10)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 12030  3.7431      19.0  6.240209   1.124021      3043.0  3.972585     33.93
# 11486  4.2875      17.0  5.235514   1.213084      1473.0  2.753271     33.72
# 995    4.8624      11.0  5.680000   1.044706      5826.0  2.741647     37.71
# 4168   4.3812      32.0  5.176360   0.936210      1661.0  3.116323     34.11
# 9788   5.3245      39.0  6.508475   1.372881       264.0  2.237288     35.91
# ...       ...       ...       ...        ...         ...       ...       ...
# 14856  4.1325      32.0  5.439619   1.085805      2152.0  2.279661     32.64
# 15811  4.2569      52.0  4.898129   1.041580       909.0  1.889813     37.76
# 8292   3.5292      36.0  3.725256   1.033276      1912.0  1.631399     33.77
# 17709  4.3782      23.0  5.204762   1.026984      2582.0  4.098413     37.33
# 3859   3.2763      29.0  4.482471   1.071786      1085.0  1.811352     34.17
#
#        Longitude
# 12030    -117.46
# 11486    -117.99
# 995      -121.75
# 4168     -118.21
# 9788     -120.51
# ...          ...
# 14856    -117.07
# 15811    -122.43
# 8292     -118.15
# 17709    -121.82
# 3859     -118.44
#
# [16512 rows x 8 columns]

# %%
# Fit a centralized GBT model for regression
reg = GradientBoostingRegressor(
    n_estimators=int(NUM_ROUNDS * (NUM_CLIENTS * FRACTION_FIT)),
    subsample=1 / NUM_CLIENTS,
    criterion="squared_error",
    init="zero",
    random_state=0,
)
reg.fit(x_train, y_train)

# Print performance metrics measured on the test data
reg_pred = reg.predict(x_test)
print("r2_score:", r2_score(reg_pred, y_test))
print("mean_squared_error:", mean_squared_error(reg_pred, y_test))
# Out:
# r2_score: 0.6720230215770214
# mean_squared_error: 0.350502708493234

# %%
# Inspect the distribution of the latitude and longitude of the samples
# There are natural clusters of samples with a similar value for the target variable
# Latitude and lognitude features will be used to split the samples in a non-iid way
geo_data = x_train[["Latitude", "Longitude"]].to_numpy()
plt.scatter(*geo_data.transpose(), c=y_train)
plt.show()

# %%
# Cluster samples based on latitude and longitude
kmeans = KMeans(NUM_CLIENTS)
train_clusters = kmeans.fit_predict(geo_data)
test_clusters = kmeans.predict(x_test[["Latitude", "Longitude"]].to_numpy())
plt.scatter(*geo_data.transpose(), c=train_clusters)
plt.show()

# %%
# Test performances of a random regressor on the test data
print("r2_score:", r2_score([y_train.mean(),] * len(y_test), y_test))
print("mean_squared_error:", mean_squared_error([y_train.mean(),] * len(y_test), y_test))
# Out:
# r2_score: -6.718290881137794e+30
# mean_squared_error: 1.3249492565081074

# %%
# Simulation of the FedLSBT algorithm useful for experimental purposes
DEBUG = True


def fit(
    X,
    y,
    *,
    base_estimator=ExtraTreeRegressor,
    n_estimators=50,
    fraction_fit=1.0,
    fraction_review=1.0,
):
    fit_clients = max(0, min(kmeans.n_clusters, int(fraction_fit * kmeans.n_clusters)))
    review_clients = max(
        0, min(kmeans.n_clusters, int(fraction_review * kmeans.n_clusters))
    )
    if DEBUG:
        print(f"[DEBUG] fit_clients: {fit_clients}, review_clients: {review_clients}")
    model = {"estimators": [], "gammas": []}
    losses = []
    y_predf = 0
    for _ in range(n_estimators):
        train_subset = np.random.choice(np.unique(kmeans.labels_), fit_clients, False)
        if DEBUG:
            print(f"[DEBUG] random clients train subset: {train_subset}")
        candidates = {"trees": [], "gamma_numerator": [], "gamma_denominator": []}
        ri = y - y_predf
        # -#-#-#-#-#-#-#-#- Client Training -#-#-#-#-#-#-#-#-#-#-#
        for i in train_subset:
            tree = base_estimator(max_leaf_nodes=MAX_LEAVES, random_state=i**2)
            tree.fit(X.iloc[train_clusters == i], ri.iloc[train_clusters == i])
            candidates["trees"].append(tree)
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        # -#-#-#-#-#-#-#-#- Client Review -#-#-#-#-#-#-#-#-#-#-#-#
        for n, i in enumerate(train_subset):
            h_k = [
                tree.predict(X.iloc[train_clusters == i])
                # if n != m
                # else np.zeros(len(X.iloc[train_clusters == i]))
                for m, tree in enumerate(candidates["trees"])
            ]
            h_k = np.stack(h_k, axis=1).T
            numerator_k = h_k @ ri.iloc[train_clusters == i]
            denominator_k = h_k @ h_k.T
            candidates["gamma_numerator"].append(numerator_k)
            candidates["gamma_denominator"].append(denominator_k)
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        # -#-#-#-#-#-#-#-#- Server Aggregate -#-#-#-#-#-#-#-#-#-#-
        gamma_numerator = sum(candidates["gamma_numerator"])
        gamma_denominator = sum(candidates["gamma_denominator"])
        gamma = np.linalg.inv(gamma_denominator) @ gamma_numerator
        gamma = gamma / (len(gamma))
        for i, tree in enumerate(candidates["trees"]):
            y_predf = y_predf + gamma[i] * tree.predict(X)
            model["estimators"].append(tree)
            model["gammas"].append(gamma[i])
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        losses.append(mean_squared_error(y_predf, y))
    return model, losses


def predict(X, model):
    y_pred = np.zeros(X.shape[0])
    for estimator, gamma in zip(model["estimators"], model["gammas"]):
        y_pred = y_pred + gamma * estimator.predict(X)
    return y_pred

# %%
# Fit the FedLSBT model
np.random.seed(0)
model, losses = fit(
    x_train,
    y_train,
    base_estimator=ExtraTreeRegressor,
    n_estimators=50,
    fraction_fit=1 / 3,
    fraction_review=1 / 3,
)
# Out:
# [DEBUG] fit_clients: 10, review_clients: 10
# [DEBUG] random clients train subset: [ 2 28 13 10 26 24 27 11 17 22]
# [DEBUG] random clients train subset: [ 5 16 20  6 13  8 11 12  2 25]
# [DEBUG] random clients train subset: [24 27 21 25 14 12 19 23 29 16]
# [DEBUG] random clients train subset: [25  6 10 22 17  7 24  2 18 11]
# [DEBUG] random clients train subset: [ 8 23 27  5 24 15  6 12 28 29]
# [DEBUG] random clients train subset: [ 5  7  9  1 25 27  4 23 29 15]
# [DEBUG] random clients train subset: [15 23 28 10 12  2 18 19 17  7]
# [DEBUG] random clients train subset: [27 11 19 26  9 16 21  2  4  8]
# [DEBUG] random clients train subset: [ 4 12 11  0  1  6  5  8 26 15]
# [DEBUG] random clients train subset: [ 9 21 18  6 22 12 10  7 15 29]
# [DEBUG] random clients train subset: [ 9  0 10  4 16 21 23  8 13  3]
# [DEBUG] random clients train subset: [ 2  5 29  6 25 15 23 12 20 26]
# [DEBUG] random clients train subset: [28 16  9  2 15  6 25 23  1 12]
# [DEBUG] random clients train subset: [17 22  4  2 14 24  0  5  8  7]
# [DEBUG] random clients train subset: [11  0 22 19 28 10 21 27 14  5]
# [DEBUG] random clients train subset: [29  2 11  5 18 26 23  6 13  8]
# [DEBUG] random clients train subset: [15 18 28 25 13 14 19 23 20 21]
# [DEBUG] random clients train subset: [ 4 29  2 14 13 17 19 26 27 10]
# [DEBUG] random clients train subset: [29  7 22 26 20  8 18  5 15 27]
# [DEBUG] random clients train subset: [ 4 17 11 19 24  1 26  5 29  7]
# [DEBUG] random clients train subset: [ 7 20 23 21  6 25 11 19 16 13]
# [DEBUG] random clients train subset: [14  8  7 12 16 10  0 26 15  3]
# [DEBUG] random clients train subset: [23  0 26 20 28  4 21 18 19 17]
# [DEBUG] random clients train subset: [10 28  9 22 27 12 16 29  2 15]
# [DEBUG] random clients train subset: [ 6 24 28  8 25 11 23 29 15 19]
# [DEBUG] random clients train subset: [24 13 14 22  3 15 11 25  0  7]
# [DEBUG] random clients train subset: [ 1  5 17 16 21  4 23 27  2 19]
# [DEBUG] random clients train subset: [ 0 28 21 18  4  7  3  8 17 20]
# [DEBUG] random clients train subset: [ 7  2 17 16 23 24  3 10 27 14]
# [DEBUG] random clients train subset: [ 8  2 18 15 13  1 29 11  9  3]
# [DEBUG] random clients train subset: [23 19  5 26  8 28  3  0 10  2]
# [DEBUG] random clients train subset: [10 28 29  9 25 24 27  6 15 19]
# [DEBUG] random clients train subset: [12 24  6  4 21  2 16 13 15 11]
# [DEBUG] random clients train subset: [ 3 21  8 26 20  2  4 18  6 12]
# [DEBUG] random clients train subset: [ 0 19 11 14 10 22 13  7 25 18]
# [DEBUG] random clients train subset: [22 10 18  7 16 27 13 28  8  6]
# [DEBUG] random clients train subset: [ 0 22  9 27 12  1 17 23 25  4]
# [DEBUG] random clients train subset: [ 6 13  4 21 17 25 10 15 20 19]
# [DEBUG] random clients train subset: [10  5 28 29  9 23  4  0 20  3]
# [DEBUG] random clients train subset: [15 19 17 22 28 29  5  4 12  8]
# [DEBUG] random clients train subset: [24  3  7  8  5 28 22 26 25  6]
# [DEBUG] random clients train subset: [19  8 22 24 15 26  1 18 20 13]
# [DEBUG] random clients train subset: [14 20 23 12 19  8  5 11 18  1]
# [DEBUG] random clients train subset: [ 9  3 23 10 27  1 14  6 19 26]
# [DEBUG] random clients train subset: [22 27 19  8  7 20 10 11  2 25]
# [DEBUG] random clients train subset: [ 8  5 15  6 12 20  9 14 25 18]
# [DEBUG] random clients train subset: [ 8 14 18 16 24  3 22 11 21 12]
# [DEBUG] random clients train subset: [16 27 14  1  9 25 15  0  7 21]
# [DEBUG] random clients train subset: [26 13  6  1 17  5 28  2  9 11]
# [DEBUG] random clients train subset: [10  6 15 29 12 22 13 19 11 26]

# %%
# Measure the performance of the FedLSBT model on the test data
print("r2_score:", r2_score(predict(x_test, model), y_test))
print("mean_squared_error:", mean_squared_error(predict(x_test, model), y_test))
# Out:
# r2_score: 0.6324162888332027
# mean_squared_error: 0.3327667678234522

# %%
# Plots about the coefficients and losses during training
plt.plot(model["gammas"][::10])
plt.plot(losses)
print("mean_gamma", sum(model["gammas"]) / len(model["gammas"]))
# Out:
# mean_gamma 0.015360015819169634

# %%
# Implementation of the FedLSBT model serialization


def tree_to_state_dict(tree: Tree) -> Dict[str, Any]:
    serialized_tree = tree.__getstate__()
    dtypes = serialized_tree["nodes"].dtype
    serialized_tree["nodes_dtype"] = [dtypes[i].str for i in range(0, len(dtypes))]
    serialized_tree["nodes"] = serialized_tree["nodes"].tolist()
    serialized_tree["values"] = serialized_tree["values"].tolist()
    return serialized_tree


def decision_tree_regressor_to_state_dict(
    model: DecisionTreeRegressor,
) -> Dict[str, Any]:
    serialized_model = model.__getstate__()
    tree = tree_to_state_dict(model.tree_)
    serialized_model["feature_names_in_"] = model.feature_names_in_.tolist()
    serialized_model["tree_"] = tree
    return serialized_model


def serialize_decision_tree_regressor(model: DecisionTreeRegressor) -> bytes:
    model_state_dict = decision_tree_regressor_to_state_dict(model)
    json_formatted = json.dumps(model_state_dict)
    return bytes(json_formatted, "utf-8")


def state_dict_to_tree(
    tree_dict: Dict[str, Any], n_features: int, n_classes: int, n_outputs: int
):
    tree_dict["nodes"] = [tuple(lst) for lst in tree_dict["nodes"]]
    names = [
        "left_child",
        "right_child",
        "feature",
        "threshold",
        "impurity",
        "n_node_samples",
        "weighted_n_node_samples",
    ]
    tree_dict["nodes"] = np.array(
        tree_dict["nodes"],
        dtype=np.dtype({"names": names, "formats": tree_dict["nodes_dtype"]}),
    )
    tree_dict["values"] = np.array(tree_dict["values"])
    tree = Tree(n_features, np.array([n_classes], dtype=np.intp), n_outputs)
    tree.__setstate__(tree_dict)
    return tree


def state_dict_to_decision_tree_regressor(model_dict: Dict[str, Any]):
    deserialized_decision_tree = DecisionTreeRegressor()
    for key, value in iter(model_dict.items()):
        if key == "feature_names_in_":
            setattr(deserialized_decision_tree, key, np.asarray(value))
        elif key != "tree_":
            setattr(deserialized_decision_tree, key, value)
    tree = state_dict_to_tree(
        model_dict["tree_"], model_dict["n_features_in_"], 1, model_dict["n_outputs_"]
    )
    deserialized_decision_tree.tree_ = tree
    return deserialized_decision_tree


def deserialize_decision_tree_regressor(
    model_serialized: bytes,
) -> DecisionTreeRegressor:
    json_formatted = str(model_serialized, "utf-8")
    model_state_dict = json.loads(json_formatted)
    return state_dict_to_decision_tree_regressor(model_state_dict)


class FederatedGradientBoostingRegressor:
    def __init__(self):
        self.estimators_ = []
        self.gammas_ = []

    def predict(self, x):
        y_pred = np.zeros(x.shape[0])
        for estimator, gamma in zip(self.estimators_, self.gammas_):
            y_pred = y_pred + gamma * estimator.predict(x)
        return y_pred

    def add_estimator(self, estimator, gamma):
        if not self.estimators_:
            self.max_features_ = estimator.max_features_
            self.n_features_in_ = estimator.n_features_in_
        for attr in ["max_features_", "n_features_in_"]:
            if getattr(self, attr) != getattr(estimator, attr):
                return
        self.estimators_.append(estimator)
        self.gammas_.append(gamma)


def gradient_boosting_to_state_dict(
    model: FederatedGradientBoostingRegressor,
) -> Dict[str, Any]:
    serialized_model = {
        "estimators_": [],
        "gammas_": model.gammas_,
    }
    if getattr(model, "max_features_", None):
        serialized_model["max_features_"] = model.max_features_
    if getattr(model, "n_features_in_", None):
        serialized_model["n_features_in_"] = model.n_features_in_
    for tree in model.estimators_:
        serialized_model["estimators_"].append(
            decision_tree_regressor_to_state_dict(tree)
        )
    return serialized_model


def state_dict_to_gradient_boosting(
    model_dict: Dict[str, Any]
) -> FederatedGradientBoostingRegressor:
    model = FederatedGradientBoostingRegressor()
    model.estimators_ = [
        state_dict_to_decision_tree_regressor(tree)
        for tree in model_dict["estimators_"]
    ]
    model.gammas_ = model_dict["gammas_"]
    if model_dict.get("max_features_", False):
        model.max_features_ = model_dict["max_features_"]
    if model_dict.get("max_features_", False):
        model.n_features_in_ = model_dict["n_features_in_"]
    return model


def serialize_gradient_boosting_regressor(
    model: FederatedGradientBoostingRegressor,
) -> bytes:
    json_formatted = json.dumps(gradient_boosting_to_state_dict(model))
    return bytes(json_formatted, "utf-8")


def deserialize_gradient_boosting_regressor(
    model_serialized: bytes,
) -> FederatedGradientBoostingRegressor:
    json_formatted = str(model_serialized, "utf-8")
    model_dict = json.loads(json_formatted)
    return state_dict_to_gradient_boosting(model_dict)


def serialize_global_model_and_candidates(
    model: Union[FederatedGradientBoostingRegressor, bytes],
    candidates: Union[List[DecisionTreeRegressor], bytes],
) -> bytes:
    if isinstance(model, bytes):
        model = deserialize_gradient_boosting_regressor(model)
    if isinstance(candidates[0], bytes):
        candidates = [deserialize_decision_tree_regressor(tree) for tree in candidates]
    serialized_models = dict(
        global_model=gradient_boosting_to_state_dict(model),
        candidate_models=[
            decision_tree_regressor_to_state_dict(tree) for tree in candidates
        ],
    )
    json_serialized = json.dumps(serialized_models)
    return bytes(json_serialized, "utf-8")

# %%
# FedLSBT client implementation with PeerReview-Flower


class FedLSBTClient(PeerReviewClient):
    def __init__(
        self,
        cid: int,
        trainset: Tuple[np.ndarray, np.array],
        testset: Tuple[np.ndarray, np.array],
    ):
        self.cid = cid
        self.trainset = trainset
        self.testset = testset

    @overrides
    def train(self, ins: TrainIns) -> TrainRes:
        parameters = ins.parameters
        model = deserialize_gradient_boosting_regressor(parameters.tensors)
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        ri = self.trainset[1] - model.predict(self.trainset[0])
        tree = ExtraTreeRegressor(
            max_leaf_nodes=MAX_LEAVES,
            random_state=self.cid**2,
        )
        tree.fit(self.trainset[0], ri)
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        res = TrainRes(
            OK_STATUS,
            Parameters(serialize_decision_tree_regressor(tree), ""),
            len(self.trainset[1]),
            {},
        )
        return res

    @overrides
    def review(self, ins: ReviewIns) -> ReviewRes:
        parameters = ins.parameters
        state_dicts = json.loads(str(parameters.tensors, "utf-8"))
        model = state_dict_to_gradient_boosting(state_dicts["global_model"])
        candidates = [
            state_dict_to_decision_tree_regressor(tree)
            for tree in state_dicts["candidate_models"]
        ]
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-##-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        res_model = self.trainset[1] - model.predict(self.trainset[0])
        res_candidates = [tree.predict(self.trainset[0]) for tree in candidates]
        res_candidates = np.stack(res_candidates, axis=1).T
        numerator_k = res_candidates @ res_model
        denominator_k = res_candidates @ res_candidates.T
        # -#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-##-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#
        res = ReviewRes(
            OK_STATUS,
            ndarrays_to_parameters([numerator_k, denominator_k]),
            len(self.trainset[1]),
            {},
        )
        return res

    @overrides
    def evaluate(self, ins: EvaluateIns) -> EvaluateRes:
        parameters, config = ins.parameters, ins.config
        model = deserialize_gradient_boosting_regressor(parameters.tensors)
        y_pred = model.predict(self.testset[0])
        loss = mean_squared_error(self.testset[1], y_pred)
        return EvaluateRes(OK_STATUS, loss, len(self.testset[1]), {})

# %%
# FedLSBT strategy implementation with PeerReview-Flower


class FederatedGradientBoostingStrategy(PeerReviewedFedAvg):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @overrides
    def aggregate_train(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, TrainRes]],
        failures: List[Union[Tuple[ClientProxy, TrainRes], BaseException]],
        parameters: Optional[Parameters] = None,
    ) -> List[Tuple[Optional[Parameters], Dict[str, Scalar]]]:
        if not results:
            raise AggregateTrainException
        # Do not aggregate if there are failures and failures are not accepted
        if not self.accept_failures and failures:
            raise AggregateTrainException

        # Save ClientProxies
        self.current_round_clients = [proxy for proxy, _ in results]

        # Collect results
        return [(fit_res.parameters, {}) for _, fit_res in results]

    # Non mi piace che ci sia FitIns nei metodi di review, aggiungere un ReviewIns e ReviewRes
    # che devono essere convertiti in FitIns e FitRes dal server prima di spedirli ai client.
    @overrides
    def configure_review(
        self,
        server_round: int,
        review_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
        parameters_aggregated: List[Optional[Parameters]],
        metrics_aggregated: List[Dict[str, Scalar]],
    ) -> List[Tuple[ClientProxy, ReviewIns]]:
        # Make instructions and configurations
        config = {}
        if self.on_fit_config_fn is not None:
            # Custom fit config function provided
            config = self.on_fit_config_fn(server_round)
        # Serialize current gloabal model and candidates
        serialized = serialize_global_model_and_candidates(
            parameters.tensors, [params.tensors for params in parameters_aggregated]
        )
        review_ins = ReviewIns(Parameters(serialized, ""), config)

        # Return client/config pairs
        return [(client, review_ins) for client in self.current_round_clients]

    @overrides
    def aggregate_review(
        self,
        server_round: int,
        review_round: int,
        results: List[Tuple[ClientProxy, ReviewRes]],
        failures: List[Union[Tuple[ClientProxy, ReviewRes], BaseException]],
        parameters: Parameters,
        parameters_aggregated: List[Optional[Parameters]],
        metrics_aggregated: List[Dict[str, Scalar]],
    ) -> List[Tuple[Optional[Parameters], Dict[str, Scalar]]]:
        if not results:
            raise AggregateReviewException
        # Do not aggregate if there are failures and failures are not accepted
        if not self.accept_failures and failures:
            raise AggregateReviewException
        # Compute gamma
        gamma_numerator = sum(
            [
                parameters_to_ndarrays(review_res.parameters)[0]
                for _, review_res in results
            ]
        )
        gamma_denominator = sum(
            [
                parameters_to_ndarrays(review_res.parameters)[1]
                for _, review_res in results
            ]
        )
        gamma = np.linalg.inv(gamma_denominator) @ gamma_numerator
        gamma = gamma / (len(gamma))
        # Return candidates parameters along with gamma
        return [
            (params, gamma_i) for params, gamma_i in zip(parameters_aggregated, gamma)
        ]

    @overrides
    def aggregate_after_review(
        self,
        server_round: int,
        parameters: Parameters,
        parameters_aggregated: List[Optional[Parameters]],
        metrics_aggregated: List[Dict[str, Scalar]],
    ) -> Optional[Parameters]:
        # Update global model with candidated weighted by computed gamma
        model = deserialize_gradient_boosting_regressor(parameters.tensors)
        for params, gamma in zip(parameters_aggregated, metrics_aggregated):
            model.add_estimator(
                deserialize_decision_tree_regressor(params.tensors), gamma
            )
        # Return the new serialized global model
        return Parameters(serialize_gradient_boosting_regressor(model), "")

    @overrides
    def stop_review(
        self,
        server_round: int,
        review_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
        parameters_aggregated: List[Optional[Parameters]],
        metrics_aggregated: List[Dict[str, Scalar]],
    ) -> bool:
        # Always stop the review process after the second review round
        return True if review_round == 2 else False

    def initialize_parameters(
        self, client_manager: ClientManager
    ) -> Optional[Parameters]:
        model = FederatedGradientBoostingRegressor()
        return Parameters(serialize_gradient_boosting_regressor(model), "")

    @overrides
    def evaluate(
        self, server_round: int, parameters: Parameters
    ) -> Optional[Tuple[float, Dict[str, Scalar]]]:
        if self.evaluate_fn is None:
            # No evaluation function provided
            return None
        eval_res = self.evaluate_fn(server_round, parameters, {})
        if eval_res is None:
            return None
        loss, metrics = eval_res
        return loss, metrics

# %%
# Setup of the federated learning simulation using PeerReview-Flower sequential simulation


def client_fn(cid: str):
    cid = int(cid)
    trainset = (
        x_train.iloc[train_clusters == cid],
        y_train.iloc[train_clusters == cid],
    )
    testset = (x_test.iloc[test_clusters == cid], y_test.iloc[test_clusters == cid])
    return FedLSBTClient(cid, cp(trainset), cp(testset))


def evaluate_fn(
    server_round: int,
    parameters: Parameters,
    config: Dict[str, fl.common.Scalar],
) -> Optional[Tuple[float, Dict[str, fl.common.Scalar]]]:
    model = deserialize_gradient_boosting_regressor(parameters.tensors)
    y_pred = model.predict(x_test)
    loss = mean_squared_error(y_test, y_pred)
    return loss, {}


strategy = FederatedGradientBoostingStrategy(
    fraction_fit=FRACTION_FIT,
    fraction_review=FRACTION_REVIEW,
    fraction_evaluate=FRACTION_EVAL,
    min_fit_clients=int(NUM_CLIENTS * FRACTION_FIT),
    min_review_clients=int(NUM_CLIENTS * FRACTION_REVIEW),
    min_evaluate_clients=int(NUM_CLIENTS * FRACTION_EVAL),
    min_available_clients=NUM_CLIENTS,
    evaluate_fn=evaluate_fn,
)
server = PeerReviewServer(strategy=strategy)

np.random.seed(0)
hist = start_simulation(
    num_clients=NUM_CLIENTS,
    client_fn=client_fn,
    server=server,
    config=ServerConfig(num_rounds=NUM_ROUNDS),
    strategy=strategy,
)
# Out:
# WARNING flower 2022-12-04 14:33:35,583 | app.py:165 | Both server and strategy were provided, ignoring strategy
# INFO flower 2022-12-04 14:33:35,587 | app.py:142 | Starting Flower simulation, config: ServerConfig(num_rounds=50, round_timeout=None)
# INFO flower 2022-12-04 14:33:39,069 | app.py:176 | Flower VCE: Ray initialized with resources: {'object_store_memory': 1228159795.0, 'CPU': 8.0, 'node:192.168.178.22': 1.0, 'memory': 2456319591.0}
# INFO flower 2022-12-04 14:33:39,071 | server.py:114 | Initializing global parameters
# INFO flower 2022-12-04 14:33:39,072 | server.py:391 | Using initial parameters provided by strategy
# INFO flower 2022-12-04 14:33:39,073 | server.py:117 | Evaluating initial parameters
# INFO flower 2022-12-04 14:33:39,075 | server.py:120 | initial parameters (loss, other metrics): 5.507926422242877, {}
# INFO flower 2022-12-04 14:33:39,076 | server.py:58 | FL starting
# DEBUG flower 2022-12-04 14:33:39,078 | server.py:246 | train_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:41,518 | server.py:261 | train_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:41,521 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:41,735 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:41,763 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:41,989 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:42,080 | server.py:178 | fit progress: (
# 	server_round: 1,
# 	centralized_loss: 4.5826874102191395,
# 	metrics: {},
# 	time_elapsed 3.0018975734710693
# )
# INFO flower 2022-12-04 14:33:42,084 | server.py:163 | evaluate_round 1: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:42,086 | server.py:246 | train_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:42,280 | server.py:261 | train_round 2 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:42,285 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:42,503 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:42,524 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:42,735 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:42,834 | server.py:178 | fit progress: (
# 	server_round: 2,
# 	centralized_loss: 3.800430199829353,
# 	metrics: {},
# 	time_elapsed 3.7559010982513428
# )
# INFO flower 2022-12-04 14:33:42,836 | server.py:163 | evaluate_round 2: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:42,838 | server.py:246 | train_round 3: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:43,043 | server.py:261 | train_round 3 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:43,049 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:43,222 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:43,242 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:43,491 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:43,579 | server.py:178 | fit progress: (
# 	server_round: 3,
# 	centralized_loss: 3.238241957540816,
# 	metrics: {},
# 	time_elapsed 4.500955581665039
# )
# INFO flower 2022-12-04 14:33:43,580 | server.py:163 | evaluate_round 3: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:43,581 | server.py:246 | train_round 4: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:43,807 | server.py:261 | train_round 4 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:43,814 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:44,018 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:44,044 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:44,313 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:44,468 | server.py:178 | fit progress: (
# 	server_round: 4,
# 	centralized_loss: 2.674955996182654,
# 	metrics: {},
# 	time_elapsed 5.390032052993774
# )
# INFO flower 2022-12-04 14:33:44,471 | server.py:163 | evaluate_round 4: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:44,472 | server.py:246 | train_round 5: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:44,707 | server.py:261 | train_round 5 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:44,714 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:44,980 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:45,013 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:45,292 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:45,450 | server.py:178 | fit progress: (
# 	server_round: 5,
# 	centralized_loss: 2.3507480964242733,
# 	metrics: {},
# 	time_elapsed 6.372355937957764
# )
# INFO flower 2022-12-04 14:33:45,451 | server.py:163 | evaluate_round 5: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:45,452 | server.py:246 | train_round 6: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:45,690 | server.py:261 | train_round 6 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:45,700 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:46,023 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:46,057 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:46,425 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:46,596 | server.py:178 | fit progress: (
# 	server_round: 6,
# 	centralized_loss: 2.066222156160415,
# 	metrics: {},
# 	time_elapsed 7.518620252609253
# )
# INFO flower 2022-12-04 14:33:46,597 | server.py:163 | evaluate_round 6: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:46,597 | server.py:246 | train_round 7: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:46,869 | server.py:261 | train_round 7 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:46,879 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:47,182 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:47,225 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:47,581 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:47,750 | server.py:178 | fit progress: (
# 	server_round: 7,
# 	centralized_loss: 1.7332452369202744,
# 	metrics: {},
# 	time_elapsed 8.672595024108887
# )
# INFO flower 2022-12-04 14:33:47,751 | server.py:163 | evaluate_round 7: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:47,751 | server.py:246 | train_round 8: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:48,046 | server.py:261 | train_round 8 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:48,059 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:48,362 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:48,425 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:48,795 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:49,017 | server.py:178 | fit progress: (
# 	server_round: 8,
# 	centralized_loss: 1.5434457917548647,
# 	metrics: {},
# 	time_elapsed 9.939513206481934
# )
# INFO flower 2022-12-04 14:33:49,018 | server.py:163 | evaluate_round 8: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:49,019 | server.py:246 | train_round 9: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:49,339 | server.py:261 | train_round 9 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:49,353 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:49,682 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:49,707 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:50,099 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:50,273 | server.py:178 | fit progress: (
# 	server_round: 9,
# 	centralized_loss: 1.3701323077898455,
# 	metrics: {},
# 	time_elapsed 11.195217370986938
# )
# INFO flower 2022-12-04 14:33:50,274 | server.py:163 | evaluate_round 9: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:50,274 | server.py:246 | train_round 10: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:50,725 | server.py:261 | train_round 10 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:50,740 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:51,117 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:51,177 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:51,599 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:51,805 | server.py:178 | fit progress: (
# 	server_round: 10,
# 	centralized_loss: 1.2501208751417188,
# 	metrics: {},
# 	time_elapsed 12.727292537689209
# )
# INFO flower 2022-12-04 14:33:51,806 | server.py:163 | evaluate_round 10: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:51,806 | server.py:246 | train_round 11: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:52,186 | server.py:261 | train_round 11 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:52,204 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:52,623 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:52,688 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:53,137 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:53,361 | server.py:178 | fit progress: (
# 	server_round: 11,
# 	centralized_loss: 1.0997353344393925,
# 	metrics: {},
# 	time_elapsed 14.28305983543396
# )
# INFO flower 2022-12-04 14:33:53,361 | server.py:163 | evaluate_round 11: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:53,362 | server.py:246 | train_round 12: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:53,826 | server.py:261 | train_round 12 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:53,844 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:54,301 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:54,379 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:54,851 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:55,104 | server.py:178 | fit progress: (
# 	server_round: 12,
# 	centralized_loss: 1.0079144168498402,
# 	metrics: {},
# 	time_elapsed 16.02577829360962
# )
# INFO flower 2022-12-04 14:33:55,104 | server.py:163 | evaluate_round 12: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:55,105 | server.py:246 | train_round 13: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:55,528 | server.py:261 | train_round 13 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:55,550 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:56,032 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:56,110 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:56,640 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:56,893 | server.py:178 | fit progress: (
# 	server_round: 13,
# 	centralized_loss: 0.9402672466668736,
# 	metrics: {},
# 	time_elapsed 17.815335035324097
# )
# INFO flower 2022-12-04 14:33:56,894 | server.py:163 | evaluate_round 13: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:56,894 | server.py:246 | train_round 14: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:57,370 | server.py:261 | train_round 14 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:57,389 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:57,864 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:57,933 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:58,472 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:33:58,736 | server.py:178 | fit progress: (
# 	server_round: 14,
# 	centralized_loss: 0.8553199057856572,
# 	metrics: {},
# 	time_elapsed 19.658287048339844
# )
# INFO flower 2022-12-04 14:33:58,737 | server.py:163 | evaluate_round 14: no clients selected, cancel
# DEBUG flower 2022-12-04 14:33:58,737 | server.py:246 | train_round 15: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:59,239 | server.py:261 | train_round 15 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:59,262 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:33:59,759 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:33:59,837 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:00,453 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:00,741 | server.py:178 | fit progress: (
# 	server_round: 15,
# 	centralized_loss: 0.8071985494495294,
# 	metrics: {},
# 	time_elapsed 21.663110733032227
# )
# INFO flower 2022-12-04 14:34:00,742 | server.py:163 | evaluate_round 15: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:00,742 | server.py:246 | train_round 16: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:01,325 | server.py:261 | train_round 16 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:01,454 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:02,099 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:02,271 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:02,965 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:03,272 | server.py:178 | fit progress: (
# 	server_round: 16,
# 	centralized_loss: 0.7573017369330547,
# 	metrics: {},
# 	time_elapsed 24.194432735443115
# )
# INFO flower 2022-12-04 14:34:03,273 | server.py:163 | evaluate_round 16: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:03,273 | server.py:246 | train_round 17: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:04,006 | server.py:261 | train_round 17 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:04,037 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:04,712 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:04,837 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:05,550 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:05,902 | server.py:178 | fit progress: (
# 	server_round: 17,
# 	centralized_loss: 0.7293158437151014,
# 	metrics: {},
# 	time_elapsed 26.823807954788208
# )
# INFO flower 2022-12-04 14:34:05,902 | server.py:163 | evaluate_round 17: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:05,903 | server.py:246 | train_round 18: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:06,567 | server.py:261 | train_round 18 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:06,599 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:07,335 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:07,461 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:08,212 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:08,571 | server.py:178 | fit progress: (
# 	server_round: 18,
# 	centralized_loss: 0.6968947011059718,
# 	metrics: {},
# 	time_elapsed 29.493337869644165
# )
# INFO flower 2022-12-04 14:34:08,572 | server.py:163 | evaluate_round 18: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:08,572 | server.py:246 | train_round 19: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:09,298 | server.py:261 | train_round 19 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:09,333 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:10,090 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:10,219 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:11,037 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:11,489 | server.py:178 | fit progress: (
# 	server_round: 19,
# 	centralized_loss: 0.6619243062408526,
# 	metrics: {},
# 	time_elapsed 32.41118884086609
# )
# INFO flower 2022-12-04 14:34:11,490 | server.py:163 | evaluate_round 19: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:11,490 | server.py:246 | train_round 20: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:12,218 | server.py:261 | train_round 20 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:12,254 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:13,042 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:13,163 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:13,998 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:14,374 | server.py:178 | fit progress: (
# 	server_round: 20,
# 	centralized_loss: 0.6454339049082266,
# 	metrics: {},
# 	time_elapsed 35.29618573188782
# )
# INFO flower 2022-12-04 14:34:14,375 | server.py:163 | evaluate_round 20: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:14,375 | server.py:246 | train_round 21: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:15,164 | server.py:261 | train_round 21 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:15,202 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:16,034 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:16,168 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:17,012 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:17,469 | server.py:178 | fit progress: (
# 	server_round: 21,
# 	centralized_loss: 0.6131148380789417,
# 	metrics: {},
# 	time_elapsed 38.391273736953735
# )
# INFO flower 2022-12-04 14:34:17,470 | server.py:163 | evaluate_round 21: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:17,470 | server.py:246 | train_round 22: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:18,282 | server.py:261 | train_round 22 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:18,322 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:19,199 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:19,357 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:20,251 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:20,654 | server.py:178 | fit progress: (
# 	server_round: 22,
# 	centralized_loss: 0.5922134270611255,
# 	metrics: {},
# 	time_elapsed 41.576029539108276
# )
# INFO flower 2022-12-04 14:34:20,654 | server.py:163 | evaluate_round 22: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:20,655 | server.py:246 | train_round 23: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:21,521 | server.py:261 | train_round 23 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:21,562 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:22,451 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:22,603 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:23,534 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:24,005 | server.py:178 | fit progress: (
# 	server_round: 23,
# 	centralized_loss: 0.567251420908878,
# 	metrics: {},
# 	time_elapsed 44.92760944366455
# )
# INFO flower 2022-12-04 14:34:24,006 | server.py:163 | evaluate_round 23: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:24,006 | server.py:246 | train_round 24: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:24,882 | server.py:261 | train_round 24 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:24,936 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:25,868 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:26,019 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:26,961 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:27,385 | server.py:178 | fit progress: (
# 	server_round: 24,
# 	centralized_loss: 0.555400147525411,
# 	metrics: {},
# 	time_elapsed 48.30717587471008
# )
# INFO flower 2022-12-04 14:34:27,386 | server.py:163 | evaluate_round 24: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:27,386 | server.py:246 | train_round 25: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:28,413 | server.py:261 | train_round 25 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:28,454 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:29,419 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:29,652 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:30,581 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:31,020 | server.py:178 | fit progress: (
# 	server_round: 25,
# 	centralized_loss: 0.5474028071532945,
# 	metrics: {},
# 	time_elapsed 51.942057847976685
# )
# INFO flower 2022-12-04 14:34:31,020 | server.py:163 | evaluate_round 25: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:31,021 | server.py:246 | train_round 26: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:31,980 | server.py:261 | train_round 26 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:32,027 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:33,033 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:33,120 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:34,232 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:34,768 | server.py:178 | fit progress: (
# 	server_round: 26,
# 	centralized_loss: 0.538089933576012,
# 	metrics: {},
# 	time_elapsed 55.69062805175781
# )
# INFO flower 2022-12-04 14:34:34,769 | server.py:163 | evaluate_round 26: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:34,770 | server.py:246 | train_round 27: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:35,748 | server.py:261 | train_round 27 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:35,803 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:36,838 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:37,009 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:38,031 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:38,498 | server.py:178 | fit progress: (
# 	server_round: 27,
# 	centralized_loss: 0.5339628891859081,
# 	metrics: {},
# 	time_elapsed 59.42013192176819
# )
# INFO flower 2022-12-04 14:34:38,499 | server.py:163 | evaluate_round 27: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:38,499 | server.py:246 | train_round 28: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:39,567 | server.py:261 | train_round 28 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:39,615 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:40,667 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:40,889 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:41,993 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:42,454 | server.py:178 | fit progress: (
# 	server_round: 28,
# 	centralized_loss: 0.5326298278533933,
# 	metrics: {},
# 	time_elapsed 63.37652516365051
# )
# INFO flower 2022-12-04 14:34:42,455 | server.py:163 | evaluate_round 28: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:42,456 | server.py:246 | train_round 29: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:43,511 | server.py:261 | train_round 29 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:43,562 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:44,645 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:44,815 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:45,927 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:46,488 | server.py:178 | fit progress: (
# 	server_round: 29,
# 	centralized_loss: 0.5200415955548986,
# 	metrics: {},
# 	time_elapsed 67.4096736907959
# )
# INFO flower 2022-12-04 14:34:46,488 | server.py:163 | evaluate_round 29: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:46,489 | server.py:246 | train_round 30: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:47,638 | server.py:261 | train_round 30 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:47,692 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:48,814 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:48,997 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:50,198 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:50,743 | server.py:178 | fit progress: (
# 	server_round: 30,
# 	centralized_loss: 0.5163340963202063,
# 	metrics: {},
# 	time_elapsed 71.66466879844666
# )
# INFO flower 2022-12-04 14:34:50,743 | server.py:163 | evaluate_round 30: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:50,743 | server.py:246 | train_round 31: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:51,879 | server.py:261 | train_round 31 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:51,939 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:53,110 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:53,282 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:54,468 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:55,036 | server.py:178 | fit progress: (
# 	server_round: 31,
# 	centralized_loss: 0.5056602140038331,
# 	metrics: {},
# 	time_elapsed 75.95788741111755
# )
# INFO flower 2022-12-04 14:34:55,036 | server.py:163 | evaluate_round 31: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:55,037 | server.py:246 | train_round 32: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:56,201 | server.py:261 | train_round 32 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:56,259 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:57,439 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:34:57,611 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:34:58,859 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:34:59,375 | server.py:178 | fit progress: (
# 	server_round: 32,
# 	centralized_loss: 0.5038487328411653,
# 	metrics: {},
# 	time_elapsed 80.2971339225769
# )
# INFO flower 2022-12-04 14:34:59,376 | server.py:163 | evaluate_round 32: no clients selected, cancel
# DEBUG flower 2022-12-04 14:34:59,376 | server.py:246 | train_round 33: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:00,601 | server.py:261 | train_round 33 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:00,760 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:01,993 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:02,164 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:03,421 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:03,960 | server.py:178 | fit progress: (
# 	server_round: 33,
# 	centralized_loss: 0.4986437959335337,
# 	metrics: {},
# 	time_elapsed 84.88241839408875
# )
# INFO flower 2022-12-04 14:35:03,961 | server.py:163 | evaluate_round 33: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:03,961 | server.py:246 | train_round 34: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:05,199 | server.py:261 | train_round 34 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:05,364 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:06,663 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:06,840 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:08,149 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:08,691 | server.py:178 | fit progress: (
# 	server_round: 34,
# 	centralized_loss: 0.48853543222394885,
# 	metrics: {},
# 	time_elapsed 89.6130223274231
# )
# INFO flower 2022-12-04 14:35:08,691 | server.py:163 | evaluate_round 34: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:08,692 | server.py:246 | train_round 35: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:10,009 | server.py:261 | train_round 35 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:10,175 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:11,422 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:11,592 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:12,903 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:13,508 | server.py:178 | fit progress: (
# 	server_round: 35,
# 	centralized_loss: 0.4888283692849701,
# 	metrics: {},
# 	time_elapsed 94.4305350780487
# )
# INFO flower 2022-12-04 14:35:13,509 | server.py:163 | evaluate_round 35: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:13,509 | server.py:246 | train_round 36: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:14,850 | server.py:261 | train_round 36 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:14,912 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:16,316 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:16,493 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:17,847 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:18,478 | server.py:178 | fit progress: (
# 	server_round: 36,
# 	centralized_loss: 0.4698643927867152,
# 	metrics: {},
# 	time_elapsed 99.40021467208862
# )
# INFO flower 2022-12-04 14:35:18,479 | server.py:163 | evaluate_round 36: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:18,479 | server.py:246 | train_round 37: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:19,862 | server.py:261 | train_round 37 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:19,923 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:21,478 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:21,655 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:23,076 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:23,688 | server.py:178 | fit progress: (
# 	server_round: 37,
# 	centralized_loss: 0.46611798287944317,
# 	metrics: {},
# 	time_elapsed 104.61027312278748
# )
# INFO flower 2022-12-04 14:35:23,689 | server.py:163 | evaluate_round 37: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:23,689 | server.py:246 | train_round 38: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:25,106 | server.py:261 | train_round 38 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:25,177 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:26,615 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:26,799 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:28,310 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:28,949 | server.py:178 | fit progress: (
# 	server_round: 38,
# 	centralized_loss: 0.4569574170274479,
# 	metrics: {},
# 	time_elapsed 109.87082719802856
# )
# INFO flower 2022-12-04 14:35:28,949 | server.py:163 | evaluate_round 38: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:28,950 | server.py:246 | train_round 39: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:30,419 | server.py:261 | train_round 39 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:30,490 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:31,894 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:32,187 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:33,665 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:34,245 | server.py:178 | fit progress: (
# 	server_round: 39,
# 	centralized_loss: 0.4579850239783804,
# 	metrics: {},
# 	time_elapsed 115.16685247421265
# )
# INFO flower 2022-12-04 14:35:34,245 | server.py:163 | evaluate_round 39: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:34,246 | server.py:246 | train_round 40: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:35,692 | server.py:261 | train_round 40 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:35,760 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:37,250 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:37,505 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:39,000 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:39,596 | server.py:178 | fit progress: (
# 	server_round: 40,
# 	centralized_loss: 0.4513538820950697,
# 	metrics: {},
# 	time_elapsed 120.51833748817444
# )
# INFO flower 2022-12-04 14:35:39,597 | server.py:163 | evaluate_round 40: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:39,597 | server.py:246 | train_round 41: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:41,101 | server.py:261 | train_round 41 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:41,171 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:42,735 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:42,922 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:44,505 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:45,104 | server.py:178 | fit progress: (
# 	server_round: 41,
# 	centralized_loss: 0.4478714500391418,
# 	metrics: {},
# 	time_elapsed 126.02619814872742
# )
# INFO flower 2022-12-04 14:35:45,105 | server.py:163 | evaluate_round 41: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:45,105 | server.py:246 | train_round 42: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:46,633 | server.py:261 | train_round 42 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:46,812 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:48,376 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:48,574 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:50,213 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:50,912 | server.py:178 | fit progress: (
# 	server_round: 42,
# 	centralized_loss: 0.44591867345016467,
# 	metrics: {},
# 	time_elapsed 131.83424282073975
# )
# INFO flower 2022-12-04 14:35:50,913 | server.py:163 | evaluate_round 42: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:50,913 | server.py:246 | train_round 43: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:52,425 | server.py:261 | train_round 43 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:52,522 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:54,167 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:54,355 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:56,044 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:35:56,723 | server.py:178 | fit progress: (
# 	server_round: 43,
# 	centralized_loss: 0.443176404630127,
# 	metrics: {},
# 	time_elapsed 137.6450605392456
# )
# INFO flower 2022-12-04 14:35:56,723 | server.py:163 | evaluate_round 43: no clients selected, cancel
# DEBUG flower 2022-12-04 14:35:56,724 | server.py:246 | train_round 44: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:35:58,322 | server.py:261 | train_round 44 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:35:58,395 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:00,069 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:00,342 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:01,947 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:36:02,560 | server.py:178 | fit progress: (
# 	server_round: 44,
# 	centralized_loss: 0.44481574445842564,
# 	metrics: {},
# 	time_elapsed 143.48227858543396
# )
# INFO flower 2022-12-04 14:36:02,561 | server.py:163 | evaluate_round 44: no clients selected, cancel
# DEBUG flower 2022-12-04 14:36:02,561 | server.py:246 | train_round 45: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:04,201 | server.py:261 | train_round 45 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:04,382 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:06,002 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:06,200 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:07,830 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:36:08,586 | server.py:178 | fit progress: (
# 	server_round: 45,
# 	centralized_loss: 0.44193908275196553,
# 	metrics: {},
# 	time_elapsed 149.5079357624054
# )
# INFO flower 2022-12-04 14:36:08,586 | server.py:163 | evaluate_round 45: no clients selected, cancel
# DEBUG flower 2022-12-04 14:36:08,587 | server.py:246 | train_round 46: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:10,310 | server.py:261 | train_round 46 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:10,391 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:12,119 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:12,420 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:14,154 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:36:14,801 | server.py:178 | fit progress: (
# 	server_round: 46,
# 	centralized_loss: 0.43710265299821044,
# 	metrics: {},
# 	time_elapsed 155.7235929965973
# )
# INFO flower 2022-12-04 14:36:14,802 | server.py:163 | evaluate_round 46: no clients selected, cancel
# DEBUG flower 2022-12-04 14:36:14,802 | server.py:246 | train_round 47: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:16,505 | server.py:261 | train_round 47 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:16,682 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:18,401 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:18,596 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:20,399 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:36:21,142 | server.py:178 | fit progress: (
# 	server_round: 47,
# 	centralized_loss: 0.43643046985354866,
# 	metrics: {},
# 	time_elapsed 162.06426525115967
# )
# INFO flower 2022-12-04 14:36:21,143 | server.py:163 | evaluate_round 47: no clients selected, cancel
# DEBUG flower 2022-12-04 14:36:21,143 | server.py:246 | train_round 48: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:22,842 | server.py:261 | train_round 48 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:22,926 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:24,671 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:24,869 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:26,677 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:36:27,382 | server.py:178 | fit progress: (
# 	server_round: 48,
# 	centralized_loss: 0.4359784299558631,
# 	metrics: {},
# 	time_elapsed 168.3038682937622
# )
# INFO flower 2022-12-04 14:36:27,382 | server.py:163 | evaluate_round 48: no clients selected, cancel
# DEBUG flower 2022-12-04 14:36:27,383 | server.py:246 | train_round 49: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:29,202 | server.py:261 | train_round 49 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:29,291 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:31,100 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:31,358 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:33,161 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:36:33,932 | server.py:178 | fit progress: (
# 	server_round: 49,
# 	centralized_loss: 0.43056414768785833,
# 	metrics: {},
# 	time_elapsed 174.8542764186859
# )
# INFO flower 2022-12-04 14:36:33,933 | server.py:163 | evaluate_round 49: no clients selected, cancel
# DEBUG flower 2022-12-04 14:36:33,933 | server.py:246 | train_round 50: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:35,733 | server.py:261 | train_round 50 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:35,817 | server.py:338 | review_round 1: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:37,664 | server.py:353 | review_round 1 received 10 results and 0 failures
# DEBUG flower 2022-12-04 14:36:37,863 | server.py:338 | review_round 2: strategy sampled 10 clients (out of 30)
# DEBUG flower 2022-12-04 14:36:39,817 | server.py:353 | review_round 2 received 10 results and 0 failures
# INFO flower 2022-12-04 14:36:40,551 | server.py:178 | fit progress: (
# 	server_round: 50,
# 	centralized_loss: 0.42966697950593563,
# 	metrics: {},
# 	time_elapsed 181.47340989112854
# )
# INFO flower 2022-12-04 14:36:40,552 | server.py:163 | evaluate_round 50: no clients selected, cancel
# INFO flower 2022-12-04 14:36:40,552 | server.py:108 | FL finished in 181.47446608543396
# INFO flower 2022-12-04 14:36:40,553 | app.py:180 | app_fit: losses_distributed []
# INFO flower 2022-12-04 14:36:40,554 | app.py:181 | app_fit: metrics_distributed {}
# INFO flower 2022-12-04 14:36:40,555 | app.py:182 | app_fit: losses_centralized [(0, 5.507926422242877), (1, 4.5826874102191395), (2, 3.800430199829353), (3, 3.238241957540816), (4, 2.674955996182654), (5, 2.3507480964242733), (6, 2.066222156160415), (7, 1.7332452369202744), (8, 1.5434457917548647), (9, 1.3701323077898455), (10, 1.2501208751417188), (11, 1.0997353344393925), (12, 1.0079144168498402), (13, 0.9402672466668736), (14, 0.8553199057856572), (15, 0.8071985494495294), (16, 0.7573017369330547), (17, 0.7293158437151014), (18, 0.6968947011059718), (19, 0.6619243062408526), (20, 0.6454339049082266), (21, 0.6131148380789417), (22, 0.5922134270611255), (23, 0.567251420908878), (24, 0.555400147525411), (25, 0.5474028071532945), (26, 0.538089933576012), (27, 0.5339628891859081), (28, 0.5326298278533933), (29, 0.5200415955548986), (30, 0.5163340963202063), (31, 0.5056602140038331), (32, 0.5038487328411653), (33, 0.4986437959335337), (34, 0.48853543222394885), (35, 0.4888283692849701), (36, 0.4698643927867152), (37, 0.46611798287944317), (38, 0.4569574170274479), (39, 0.4579850239783804), (40, 0.4513538820950697), (41, 0.4478714500391418), (42, 0.44591867345016467), (43, 0.443176404630127), (44, 0.44481574445842564), (45, 0.44193908275196553), (46, 0.43710265299821044), (47, 0.43643046985354866), (48, 0.4359784299558631), (49, 0.43056414768785833), (50, 0.42966697950593563)]
# INFO flower 2022-12-04 14:36:40,557 | app.py:183 | app_fit: metrics_centralized {}

# %%
# Get trained FedLSBT model and test performances on test data
model = deserialize_gradient_boosting_regressor(server.parameters.tensors)
y_pred = model.predict(x_test)
print(f"r2: {r2_score(y_test, y_pred)}")
print(f"mse: {mean_squared_error(y_test, y_pred)}")
# Out:
# r2: 0.6759612061853564
# mse: 0.42966697950593563

# %%
# Plot model losses during training and trees coefficients
plt.plot([l[1] for l in hist.losses_centralized])
plt.plot(model.gammas_[::10])
sum(model.gammas_) / len(model.gammas_)
# Out:
# 0.015167933270857565
